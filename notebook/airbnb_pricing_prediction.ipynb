# %% [markdown]
# # __Group Assignment - Predicting Airbnb Listing Prices in Brisbane, Australia__

# %% [markdown]
# ---
#
# **Kaggle Competition Deadline:** Friday, 5 June 2026 at 3:00 PM (Week 13)
# **Assignment Due Date (iLearn):** Friday, 5 June 2026 at 11:59 PM (Week 13)
# **Total Marks:** 30
#
# **Overview**
# In this group assignment, you will form a team of three students and participate in a forecasting competition on Kaggle.

# %% [markdown]
# ---
# ### General Instructions
#
# - Each team member must create a Kaggle account and join the competition using the link:
#   https://www.kaggle.com/t/554f205a43a94920943d5227ae9dcbdb
#
# - Form a team of three students:
#   Choose a team leader who will create the team and invite the other members
#   The team name must begin with the unit code
#
# - All team members are expected to contribute to all tasks.
#   Each member must take primary responsibility for one of the three tasks.
#
# - Your predictions must be generated using models developed in this assignment.
#   **A mark of zero will be awarded if your submitted forecasts cannot be reproduced from your code.**
#
# - All results must be clearly presented and directly verifiable from your outputs and explanations.
#
# - All written answers must be written in clear and complete sentences, supported by relevant tables, summary statistics, and visualisations where appropriate.

# %% [markdown]
# <hr style="width:20%;margin-left:0;">
#
# ### Marks
#
# - **Total Marks:** 30 (across 3 tasks)
#
# - **Individual Mark Allocation:**
#   Each student’s mark is calculated as:
#   **0.5 × overall group assignment mark (%) + 0.5 × individual task mark (%)**,
#   with the combined percentage then converted to a mark out of 30.

# %% [markdown]
# <hr style="width:20%;margin-left:0;">
#
# ### Assignment Submission
#
# 1. **Kaggle Submission:**
#    - Submit your team’s forecasts on Kaggle to be ranked on the leaderboard
# 2. **iLearn Submission (team leader only):**
#    - Submit the assignment as a Jupyter notebook, renamed to your **Kaggle team name**
#    - The notebook must include:
#      - Names and student ID numbers of all team members
#      - Your Kaggle team name
#    - Submit **one 15-minute video presentation** of your work
#      - A penalty of **5 marks will be deducted per task** if a video presentation is not provided

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### <span style="background-color: yellow;">Fill out the following information
#
# - Team Name on Kaggle: `BUSA3020_Dataholic`
# - Team Leader and Team Member 1: `Dieu Linh Ngo `
# - Team Member 2: `Phuong Linh Ngo`
# - Team Member 3: `Quynh Huong Nguyen`

# %% [markdown]
# Some useful pre-defined functions

# %% [markdown]
# ---
# ---
#
# ## Task 1: Problem Description and Exploratory Data Analysis (EDA)
#
# **Total Marks: 10**
#
# - Based on the Competition Overview, datasets, and additional information provided on Kaggle, along with insights gained from your own research (including relevant academic sources such as Google Scholar), answer the following questions.
# - Do not discuss any predictive models in this task.
#
#
# ---

# %% [markdown]
# Student in charge of this task: `Phuong Linh Ngo`

# %%
# Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import re

# %%
# Load data
raw_train_df = pd.read_csv('train.csv')
raw_test_df = pd.read_csv('test.csv')

train_df = raw_train_df.copy()
test_df = raw_test_df.copy()
train_df.head()
# Out:
#    ID       source                                             name  \
# 0   0  city scrape                                        The Nestt
# 1   1  city scrape  Bayside Bliss - By the Water & Near the Airport
# 2   2  city scrape      Cozy 1 Bedroom Apartment with Infinity Pool
# 3   3  city scrape                  City Stay-Executive 1.5 Bedroom
# 4   4  city scrape    Private Oasis! 3Bed/2Bath/1Car ~ 5mins to CBD
#
#                                          description  \
# 0  Enjoy a memorable visit when you stay in this ...
# 1  Relax by the water and close to the airport, B...
# 2  My stunning apartment is located in one of the...
# 3  Experience modern urban living in our stylish ...
# 4  Brisbane inner-city living at its best! <br />...
#
#                                neighborhood_overview    host_id host_name  \
# 0                                                NaN   38029254      Mark
# 1  Wynnum is nestled along Brisbane's sunny south...   33488214    Claire
# ...

# %% [markdown]
# Student in charge of this task: `Phuong Linh Ngo`

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 1. Forecasting Problem (2 marks)
# In approximately **300 words**, explain what we are trying to predict and how this problem can be applied in a real-world context.
# Discuss who may benefit from these predictions and how they might use them.

# %% [markdown]
# ---- Add your written answer here ------

# %% [markdown]
#  **a. Project back ground and aim**
#
# AirBnB is a internet market for shorterm home and apartment rentals [1]. One the operating challenges that hosts face is determining the optimal highly rent price to maximize their profit. But there is no easy to access methods t determine the best price charged per night because price are becoming more complicated in the context of economy [2]
#
# <p align="center">
#   <img src="ranking_score%20_image/header.png" alt="image" width="900">
# </p>
#
# This report & competition aims to predict the nightly listing price of Airbnb properties in Brisbane, Australia uses regression and other machine learning models. Given a set of listing attributes such as location, room type, number of bedrooms, and host characteristics, the goal is to build a model that accurately estimates the price a host charges per night. The task involves identifying the key determinants of Airbnb prices and quantifying their relationship with nightly rates.
#
# **b. Data Description**
#
# This is a supervised regression problem, where the target variable is a continuous numerical value - the nightly price in Australian dollars. The dataset contains 65 numerical and categorical features (including price-target variable on train set), requiring appropriate preprocessing techniques such as missing value handling, feature engineering, and categorical encoding before model development.
#
# **c. Who benefits**
#
# Beyond prediction accuracy, the project can provide insights for pricing strategies of the hosts and other stakeholders, which listing characteristics contribute most strongly to pricing decisions in the Brisbane market.[4]. This is particularly useful for new hosts who lack experience in the market.
#
# Travellers benefit indirectly - a well-functioning pricing model helps ensure listings are priced fairly relative to their features and location, making it easier to identify good value options.
#
# Property investors and real estate analysts can also use price predictions to assess the short-term rental potential of properties in different Brisbane neighbourhoods before making investment decisions. Local governments and tourism authorities may also benefit from understanding pricing patterns, as short-term rental markets can influence tourism activity, housing availability, and regional economic development.
#
# Brisbane is a growing tourism and business destination, with demand for short-term accommodation increasing due to major events, the upcoming 2032 Olympic Games, and population growth. Understanding what drives Airbnb prices in this market is therefore both timely and commercially relevant.
#
# **Overall**, this forecasting problem sits at the intersection of real estate, tourism, and data science. It not only seeks to generate accurate price predictions but also provides valuable insights into the factors that influence Airbnb pricing behaviour in Brisbane's rapidly evolving short-term rental market.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 2. Evaluation Criteria (2 marks)
# Describe the evaluation metric used in this competition to assess forecasting performance.
# Provide the equation and discuss its advantages and potential limitations.

# %% [markdown]
# ---- Add your written answer here ------

# %% [markdown]
# #### **Evaluation Metric: Mean Absolute Percentage Error (MAPE)**
#
# The competition evaluates submissions using **Mean Absolute Percentage Error (MAPE)**, defined as:
#
# $$MAPE = \frac{1}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right| \times 100$$
#
# where $y_i$ is the actual nightly price, $\hat{y}_i$ is the predicted price, and $n$ is the total number of listings.
#
# **Advantages**
#
# - *Interpretability:* MAPE expresses prediction error as a percentage, making it immediately intuitive for non-technical stakeholders such as hosts and investors. For example, a MAPE of 20% means the model's predictions deviate from actual prices by 20% on average. This is far more meaningful than an absolute metric like MAE - a `$50` error on a `$100` listing is catastrophic, whereas the same `$50` error on a `$1,000` listing is negligible. MAPE captures this distinction naturally.
#
# - *Scale independence:* MAPE expresses errors as percentages rather than absolute dollar values, allowing performance to be compared across listings with very different price levels. This is particularly appropriate for Airbnb price prediction, where listing prices range from budget accommodation to luxury properties. Unlike MAE, the metric accounts for the relative importance of an error compared with the listing's actual price.
#
# - *Robustness across heterogeneous listings:* Brisbane Airbnb listings vary substantially in price, property type, and location. By evaluating prediction errors as percentages rather than dollar amounts, MAPE provides a standardised measure of forecasting performance across both budget and luxury properties.
#
# - *Comparability:* Alignment with competition objective: Since submissions are ranked directly using MAPE, optimising this metric ensures that model development and evaluation are aligned with the competition's scoring criterion. Models with lower validation MAPE are expected to achieve better leaderboard performance.
#
# - *Detecting overfitting and underfitting:* Although MAPE is not specifically designed to detect overfitting, comparing training and validation MAPE provides a useful diagnostic tool. A substantially lower training MAPE than validation MAPE suggests overfitting, whereas consistently high values on both datasets may indicate underfitting.
#
# - *Alignment with competition objective:* Since competition rankings are based directly on MAPE, optimising this metric during model development ensures consistency between model evaluation and final competition performance. Models that achieve lower validation MAPE are more likely to perform well on the leaderboard.
#
# **Limitations**
#
# - *Division by zero:* MAPE is mathematically undefined when the actual price is zero. While this is a theoretical concern, the minimum listing
# price in this dataset is $36 AUD per night, meaning division by zero cannot occur in practice. However, this remains a general limitation of MAPE when applied to other datasets.
#
# - *Sensitivity to low-priced listings:* Listings with very low prices produce disproportionately large percentage errors even from small
# absolute mistakes. For example, a `$10` error on a `$36` listing contributes 27.8% to MAPE, whereas the same `$10` error on a `$300` listing contributes only 3.3%. This asymmetry can pull the overall MAPE upward and bias models towards predicting higher prices.
#
# - *No systematic bias detection:* Like most error metrics, MAPE does not capture whether the model systematically over- or under-predicts. A
# separate bias analysis would be required to determine if predictions are consistently skewed in one direction.
#
# - *Asymmetric penalty structure:* MAPE penalises errors on low-priced listings more heavily than identical dollar errors on expensive listings. Consequently, model optimisation may place disproportionate emphasis on accurately predicting cheaper properties while paying less attention to high-value listings.
#
# **Despite these limitations, MAPE remains an appropriate evaluation metric because it aligns directly with the competition objective while providing an interpretable and scale-independent measure of forecasting accuracy.**

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 3. Missing Values (2 marks)
# Identify and report the number of missing values in the dataset using appropriate summaries.
# Clearly interpret your findings for both the training and test datasets.

# %% [markdown]
# ---- Add your written answer here ------

# %%
# Have a look at data at glance
train_df.head()
# Out:
#    ID       source                                             name  \
# 0   0  city scrape                                        The Nestt
# 1   1  city scrape  Bayside Bliss - By the Water & Near the Airport
# 2   2  city scrape      Cozy 1 Bedroom Apartment with Infinity Pool
# 3   3  city scrape                  City Stay-Executive 1.5 Bedroom
# 4   4  city scrape    Private Oasis! 3Bed/2Bath/1Car ~ 5mins to CBD
#
#                                          description  \
# 0  Enjoy a memorable visit when you stay in this ...
# 1  Relax by the water and close to the airport, B...
# 2  My stunning apartment is located in one of the...
# 3  Experience modern urban living in our stylish ...
# 4  Brisbane inner-city living at its best! <br />...
#
#                                neighborhood_overview    host_id host_name  \
# 0                                                NaN   38029254      Mark
# 1  Wynnum is nestled along Brisbane's sunny south...   33488214    Claire
# ...

# %%
# Create some useful pre-define function:
def missing_summary(df, name):
    """
    Create a dataframe, then calculate the number of null and blank value.
    Only report the columns that have missing values and percentage of missing.
    
    Parameter:
    df (DataFrame)
        The dataframe used to check for missing values
    name (dataset)
        Train or test set
    
    Return:
    completed_report (DataFrame)
        The report table including the number of null, and their percentage in total
    """
    missing = df.isnull().sum()
    missing = missing[missing > 0].sort_values(ascending=False)
    pct = (missing / len(df) * 100).round(2)
    summary = pd.DataFrame({'Missing Count': missing, 'Missing (%)': pct})
    print(f"  {name}  —  {df.shape[0]} rows x {df.shape[1]} cols")
    print(f"{'='*40}")
    print(summary.to_string())
    return summary

train_missing = missing_summary(train_df, 'TRAIN')
test_missing  = missing_summary(test_df,  'TEST')


def classify_missing(pct):
    """
    Classify a column's missing-value percentage into a severity band.
    Used to group columns by how much data they are missing.

    Parameter:
    pct (float)
        The percentage of missing values in a column

    Return:
    severity (str)
        The severity label - 'Low (<5%)', 'Moderate (5-30%)', or 'High (>30%)'
    """
    if pct < 5:
        return 'Low (<5%)' 
    elif pct < 30:
        return 'Moderate (5–30%)' 
    else:
        return 'High (>30%)'
# Out:
#   TRAIN  —  3735 rows x 65 cols
# ...
#                              Missing Count  Missing (%)
# host_neighbourhood                    3599        96.36
# neighborhood_overview                 1981        53.04
# host_about                            1492        39.95
# host_location                          818        21.90
# reviews_per_month                      437        11.70
# review_scores_rating                   437        11.70
# review_scores_accuracy                 437        11.70
# review_scores_cleanliness              437        11.70
# review_scores_checkin                  437        11.70
# review_scores_communication            437        11.70
# last_review                            437        11.70
# first_review                           437        11.70
# review_scores_location                 437        11.70
# review_scores_value                    437        11.70
# host_response_rate                     287         7.68
# ...

# %%
for name, df in [('TRAIN', train_df), ('TEST', test_df)]:
    total_cols = df.shape[1]
    cols_with_missing = df.isnull().any().sum()
    cols_no_missing = total_cols - cols_with_missing
    
    print(f"\n{'='*45}")
    print(f"  {name} — {df.shape[0]} rows x {total_cols} cols")
    print(f"{'='*45}")
    print(f"  Columns with at least 1 missing value: {cols_with_missing} ({cols_with_missing/total_cols*100:.1f}%)")
    print(f"  Columns with NO missing values:        {cols_no_missing} ({cols_no_missing/total_cols*100:.1f}%)")
# Out:
# ...
#   TRAIN — 3735 rows x 65 cols
# ...
#   Columns with at least 1 missing value: 33 (50.8%)
#   Columns with NO missing values:        32 (49.2%)
#
# ...
#   TEST — 1601 rows x 64 cols
# ...
#   Columns with at least 1 missing value: 25 (39.1%)
#   Columns with NO missing values:        39 (60.9%)

# %%
# Report missing for train and test set
if not train_missing.empty:
    train_missing['Severity'] = train_missing['Missing (%)'].apply(classify_missing)
    print("\n Missing Severity (Train) ")
    print(train_missing.groupby('Severity')['Missing Count'].count())
    print(train_missing.to_string())

if not test_missing.empty:
    test_missing['Severity'] = test_missing['Missing (%)'].apply(classify_missing)
    print("\n Missing Severity (Test) ")
    print(test_missing.groupby('Severity')['Missing Count'].count())
    print(test_missing.to_string())
# Out:
#  Missing Severity (Train)
# Severity
# High (>30%)          3
# Low (<5%)           16
# Moderate (5–30%)    14
# Name: Missing Count, dtype: int64
#                              Missing Count  Missing (%)          Severity
# host_neighbourhood                    3599        96.36       High (>30%)
# neighborhood_overview                 1981        53.04       High (>30%)
# host_about                            1492        39.95       High (>30%)
# host_location                          818        21.90  Moderate (5–30%)
# reviews_per_month                      437        11.70  Moderate (5–30%)
# review_scores_rating                   437        11.70  Moderate (5–30%)
# review_scores_accuracy                 437        11.70  Moderate (5–30%)
# review_scores_cleanliness              437        11.70  Moderate (5–30%)
# review_scores_checkin                  437        11.70  Moderate (5–30%)
# review_scores_communication            437        11.70  Moderate (5–30%)
# ...

# %% [markdown]
# **Training Dataset (3735 rows, 65 columns)**
#
# - The training dataset contains 33 columns with at least one missing value, while 32 columns are complete. Missing values arise due to several reasons - including optional fields that hosts choose not to fill in, and information that simply does not exist for certain listings (e.g. review scores for listings with no reviews).
#
# - Missing values are classified into three types:
#
# > MCAR (Missing Completely at Random)
#
# - `host_neighbourhood` (96.36%), `neighborhood_overview` (53.04%), and `host_about` (39.95%) are optional free-text fields that hosts simply choose not to complete, regardless of their listing quality or price.
# - The missingness appears unrelated to other observed variables and is therefore broadly consistent with MCAR. MCAR data can be removed without introducing bias. Since these columns exhibit substantial missingness and consist primarily of optional text descriptions, they will be considered for removal in Task 2.
#
# > MAR (Missing at Random)
#
# - All review score columns and `reviews_per_month` share exactly 437 missing values (11.70%).
# - This is because listings with `number_of_reviews = 0` have no scores to report - the missingness is explained by another observed variable, which is the definition of MAR.
# - Similarly, `host_response_rate` (7.68%) and `host_acceptance_rate` (5.38%) are likely missing for newer hosts who have not yet established a response policy. MAR data can lead to biased results if not handled properly. These will be imputed using median (numerical) or mode (categorical) in Task 2.
#
# > MNAR (Missing Not at Random)
#
# - No strong evidence of MNAR was found in this dataset - all missingness patterns can be explained by observable variables, as described above.
#
# _Low missingness (<5%) - 16 columns_
#
# Features such as `bedrooms` (0.05%), `beds` (0.08%), and `bathrooms_text` (0.16%) have very few missing values occurring essentially at random. These will be safely imputed using mean/median/mode imputation via `SimpleImputer` from scikit-learn in Task 2.
#
# **Test Dataset (1601 rows, 64 columns)**
#
# The test dataset shows a consistent pattern - 25 columns with missing values across the same three severity groups: High (3), Moderate (13), and Low (9). The similarity between train and test confirms that missingness is a systematic characteristic of the data rather than a quality issue. All imputation strategies will be applied consistently to both datasets in Task 2.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 4. Univariate Data Analysis (2 marks)
# Present and discuss key *univariate* characteristics of the training data.
# Use appropriate summary statistics and visualisations (e.g. histograms for numerical variables, bar charts for categorical variables) to support your analysis.
# For example you may consider variables such as price, room type, number of listings per host, availability, or geographical location.

# %% [markdown]
# ---- Add your written answer here ------

# %%
# Price has "$" and "," and it is a object -> need to remove the signs & change to float
train_df['price'] = train_df['price'].str.replace(r'[$,]', '', regex=True).astype(float)
print(train_df['price'].dtype)
print(train_df['price'].head())
# Out:
# float64
# 0     97.0
# 1    205.0
# 2    186.0
# 3    157.0
# 4    300.0
# Name: price, dtype: float64

# %% [markdown]
# - In this time, we'll chose to focus this analysis on features that we think may affect the price of an Airbnb unit in its intuition._
#
# Also look at `price` as it is our target
#
# We quickly clean the price var before analyzing because currently, `price` is an object, we need to convert it into float so we can have a look at its distribution.

# %%
# Choose some key numeric variable to have a look
cols = ['price', 'minimum_nights', 'availability_365', 
        'number_of_reviews', 'accommodates', 'bathrooms', 'review_scores_rating', 'host_listings_count']

train_df[cols].describe().round(2)
# Out:
#          price  minimum_nights  availability_365  number_of_reviews  \
# count  3735.00          3735.0           3735.00            3735.00
# mean    230.08             4.0            198.40              50.60
# std     194.65            15.3            119.51              90.08
# min      36.00             1.0              0.00               0.00
# 25%     129.00             1.0             83.00               4.00
# 50%     193.00             2.0            192.00              18.00
# 75%     267.00             3.0            322.00              56.00
# max    5000.00           500.0            365.00            1130.00
#
#        accommodates  bathrooms  review_scores_rating  host_listings_count
# count       3735.00    3730.00               3298.00              3733.00
# mean           3.70       1.42                  4.74                50.07
# std            2.31       0.71                  0.37               111.88
# ...

# %% [markdown]
# **1. Price**
#
# - The mean price is `$230.08`, which is notably higher than the median of `$193.00`.
#
# ==> This gap between mean and median indicates that the distribution is pulled upward by a small number of extremely high-priced listings. The histogram shows that the highest concentration of listings lies within the lower price ranges (approximately `$50–$150` per night).
#
# - The standard deviation of `$194.65` is nearly as large as the mean itself, indicating extremely high variability in prices across listings. The variance of `$37,868.82` further confirms this spread. The range is very wide at `$4,964` (`$36-$5,000`), reflecting the coexistence of budget listings and ultra-luxury properties.
#
# - The distribution is strongly right-skewed. This positive skew is driven by a small number of premium and luxury listings that charge significantly above the typical market rate. The presence of several extremely expensive listings suggests that the distribution contains significant outliers.
#
# ==> The price distribution reflects a two-tier Brisbane Airbnb market - a large majority of budget to mid-range listings (below `$267`) and a small segment of luxury properties commanding premium prices. Overall, the distribution indicates that while most Airbnb listings in Brisbane are moderately priced, a relatively small number of luxury properties contribute disproportionately to the upper end of the market.

# %%
# Distribution plot for price and log price
plot_data = train_df[train_df['price'].notna()]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))

# Left: Price distribution
sns.histplot(data=plot_data, x='price', bins=50, color='#4393C3', ax=ax1)
ax1.axvline(plot_data['price'].mean(),
           color='#B2182B', linestyle='--', linewidth=1.5,
           label=f"Mean: ${plot_data['price'].mean():.2f}")
ax1.axvline(plot_data['price'].median(),
           color='#2166AC', linestyle='--', linewidth=1.5,
           label=f"Median: ${plot_data['price'].median():.2f}")
ax1.set_title('Price Distribution of all Airbnb units')
ax1.set_xlabel('Price (AUD)')
ax1.set_ylabel('Count of units')
ax1.legend()

# Right: Log price distribution
log_price = np.log(plot_data['price'])
sns.histplot(log_price, bins=50, color='#D6604D', ax=ax2)
ax2.axvline(log_price.mean(),
           color='#B2182B', linestyle='--', linewidth=1.5,
           label=f"Mean: {log_price.mean():.2f}")
ax2.axvline(log_price.median(),
           color='#2166AC', linestyle='--', linewidth=1.5,
           label=f"Median: {log_price.median():.2f}")
ax2.set_title('Log Price Distribution of all Airbnb units')
ax2.set_xlabel('Log Price (log AUD)')
ax2.set_ylabel('Count of units')
ax2.legend()

plt.tight_layout()

# %% [markdown]
# **2. Minimum Nights**
#
# The mean minimum nights is 4.0, while the median is only 2.0, and the mode falls at 1 night. The large gap between mean and median indicates that a small number of listings with very high minimum night requirements are pulling the average upward, while the typical host requires just 1-2 nights minimum stay.
#
# The standard deviation of 15.3 is nearly 4 times the mean, reflecting extreme variability. The range spans from 1 to 500 nights, an extraordinarily wide spread. The IQR of just 2 nights (Q1=1, Q3=3) confirms that the central 50% of listings cluster tightly around very short minimum stays, while the outliers in the upper tail are extreme.
#
# The histogram reveals an extremely right-skewed distribution, with the vast majority of listings concentrated within the lowest minimum-night categories and only a small number of observations extending into the upper tail. This is one of the most extreme cases of right skew in the dataset, suggesting the presence of a small but distinct group of hosts who use Airbnb for medium to long-term rentals rather than short-term stays.

# %%
# Distribution plot for minimum nights and log minimum nights
plot_data = train_df[train_df['minimum_nights'].notna()]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))

# Left: Minimum night original distribution
sns.histplot(data=plot_data, x='minimum_nights', bins=50, color='#4393C3', ax=ax1)
ax1.axvline(plot_data['minimum_nights'].mean(),
           color='#B2182B', linestyle='--', linewidth=1.5,
           label=f"Mean: ${plot_data['minimum_nights'].mean():.2f}")
ax1.axvline(plot_data['minimum_nights'].median(),
           color='#2166AC', linestyle='--', linewidth=1.5,
           label=f"Median: ${plot_data['minimum_nights'].median():.2f}")
ax1.set_title('Distribution of Minimum Nights')
ax1.set_xlabel('Minimum Nights')
ax1.set_ylabel('Count of units')
ax1.legend()

# Right: Log minimum nights distribution
log_price = np.log(plot_data['minimum_nights'])
sns.histplot(log_price, bins=50, color='#D6604D', ax=ax2)
ax2.axvline(log_price.mean(),
           color='#B2182B', linestyle='--', linewidth=1.5,
           label=f"Mean: {log_price.mean():.2f}")
ax2.axvline(log_price.median(),
           color='#2166AC', linestyle='--', linewidth=1.5,
           label=f"Median: {log_price.median():.2f}")
ax2.set_title('Log Distribution of Minimum Nights')
ax2.set_xlabel('Log Minimum Nights')
ax2.set_ylabel('Count of units')
ax2.legend()

plt.tight_layout()

# %% [markdown]
# **3. Room Type**
#
# Room type is a categorical variable, so the appropriate measure of central tendency is the mode. The mode is Entire home/apt, which is by far the most frequently occurring category with approximately 2,800 listings (~75% of all listings).
#
# - `Entire home/apt`: around 2,800 listings (~75%)
# - `Private room`: around 880 listings (~24%)
# - `Shared room`: around 30 listings (<1%)
# - `Hotel room`: around 25 listings (<1%)
#
# The distribution is highly imbalanced — Entire home/apt and Private room together account for nearly 99% of all listings, while Shared room and Hotel room are negligible. This extreme concentration in two categories indicates very low diversity in room type across the dataset.
#
# The bar chart shows a distribution that is heavily concentrated in a small number of categories. Listing counts decline sharply from Entire home/apt to Private room and then fall to near zero for Shared room and Hotel room. This pattern reflects a market dominated by whole-property and private-room accommodation.
#
# The dominance of Entire home/apt (~75%) reflects Brisbane's Airbnb market structure, where most hosts rent out whole properties rather than individual rooms. In contrast, Private rooms represent a smaller but still significant segment of the market, while Shared rooms and Hotel rooms account for only a very small proportion of listings. Overall, the distribution highlights a strong preference for independent accommodation among both hosts and guests in Brisbane.

# %%
# Count variable distribution for Room Type
order = train_df['room_type'].value_counts().index
sns.countplot(data=train_df, x='room_type', order=order, hue='room_type',
              palette='RdBu', legend=False)
plt.title('Distribution of Room Type')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('room_type.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# **4. Neighbourhood**
#
# As a categorical variable, the mode is Brisbane City, which has the highest listing count at approximately 560 listings - nearly twice the count of the second-ranked neighbourhood, South Brisbane (~310 listings).
#
# - `Brisbane City`:        ~560 listings
# - `South Brisbane`:       ~310 listings
# - `Fortitude Valley`:     ~280 listings
# - `Newstead-Bowen Hills`: ~155 listings
# - `Spring Hill`:          ~145 listings
# - `New Farm`:             ~100 listings
# - `Kangaroo Point`:       ~100 listings
# - `Rocklea-Acacia Ridge`: ~95 listings
# - `West End`:             ~90 listings
# - `Sunnybank`:            ~75 listings
#
# The distribution across neighbourhoods is highly uneven. Brisbane City dominates with more than double the listings of South Brisbane. The count drops sharply after the top 3 neighbourhoods, indicating a high concentration of listings in a small number of inner-city suburbs.
#
# The bar chart reveals a highly concentrated distribution, with listing counts declining rapidly beyond the top three neighbourhoods.
#
# The strong geographic concentration in inner-city neighbourhoods reflects the demand-driven nature of Airbnb accommodation. Tourists and business travellers are more likely to prefer central locations with convenient access to the CBD, entertainment precincts, restaurants, and public transport. The dominance of Brisbane City, South Brisbane, and Fortitude Valley suggests that Airbnb activity is concentrated in areas with high visitor demand, while outer suburbs such as Sunnybank and Rocklea-Acacia Ridge contain comparatively fewer listings.

# %%
# Bar chart for Neighbourhood
plt.figure(figsize=(10, 6))
top10 = train_df['neighbourhood_cleansed'].value_counts().head(10)
sns.barplot(x=top10.values, y=top10.index,
            hue=top10.index, palette='RdBu', legend=False)
plt.title('Top 10 Neighbourhoods by Listing Count')
plt.xlabel('Number of Listings')
plt.ylabel('Neighbourhood')
plt.tight_layout()
plt.show()

# %% [markdown]
# **5. Availability (365 days)**
#
# The mean availability is 198.4 days and the median is 192 days, indicating that on average, listings are available for just over half the year. The mean and median are relatively close, suggesting that unlike price and minimum nights, this variable does not have extreme outliers pulling the mean in one direction. The highest concentration of observations occurs in the 330-365 day range, indicating that many hosts keep their listings available for most of the year.
#
# The histogram reveals a clearly bimodal distribution - there are _two distinct peaks_: one around 0-75 days and another, larger peak around 300-365 days, with a noticeable trough in the 175-250 day range. This bimodal pattern is unusual and indicates that the dataset contains two fundamentally different types of hosts rather than a single homogeneous population. The larger peak around 330–365 days suggests that a substantial proportion of hosts maintain near year-round availability.
#
# The bimodal distribution highlights two distinct hosting strategies within the Brisbane Airbnb market. Some hosts appear to make their properties available only occasionally, possibly during peak travel periods or when temporarily away from home. In contrast, another large group maintains near year-round availability, suggesting a more commercial or professional approach to hosting.

# %%
# Histogram for Avalability
plt.figure(figsize=(8, 5))
sns.histplot(train_df['availability_365'], bins=30, color='#4393C3')
plt.title('Distribution of Availability (365 days)')
plt.xlabel('Days Available per Year')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('availability.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# **6. Number of Reviews**
#
# The mean number of reviews is 50.6, while the median is only 18 and the mode falls in the 0-25 range. The large gap between mean (50.6) and median (18) - nearly three times - indicates that a small number of highly active listings with hundreds of reviews are pulling the average upward significantly, while the typical listing has accumulated far fewer reviews.
#
# The standard deviation of 90.08 is nearly five times the median, reflecting extreme variability across listings. The range spans from 0 to 1,130 reviews - an enormous spread. The IQR of 52 reviews (Q1=4, Q3=56) confirms that the central 50% of listings have between 4 and 56 reviews, while the upper tail extends dramatically to 1,130. This extreme dispersion suggests the presence of a small number of very popular, long-established listings that have accumulated reviews over many years.
#
# The histogram shows one of the most strongly right-skewed distributions in the dataset. Even with the x-axis limited to 200 reviews, over 2,000 listings fall within the first bin (0-25 reviews), with counts dropping sharply thereafter. The distribution has a very steep left peak and a long, gradually declining right tail - a classic exponential decay shape. The true maximum of 1,130 reviews lies far beyond the visible range, highlighting the extreme concentration at low values.
#
# The concentration of listings with fewer than 25 reviews suggests that the Brisbane Airbnb market is characterised by many relatively new or less frequently booked properties. Conversely, the small number of listings with exceptionally high review counts indicates a group of established listings that have maintained strong occupancy over long periods. The large disparity between these groups highlights considerable variation in listing popularity and host experience across the market.

# %%
# Histogram for Number of Review
plt.figure(figsize=(8, 5))
sns.histplot(train_df['number_of_reviews'], bins=50, color='#4393C3')
plt.title('Distribution of Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Count')
plt.xlim(0, 200)
plt.show()

# %% [markdown]
# **7. Accommodates**
#
# The mean number of guests accommodated is 3.70, the median is 3, and the mode is 2 - the most frequently occurring value with approximately 1,430 listings. The mode being lower than both mean and median indicates that while 2-guest listings dominate, larger properties pull the average upward.
#
# The standard deviation of 2.31 indicates moderate spread around the mean. The range spans from 1 to 16 guests, reflecting a diverse mix of small studio apartments and large group properties. The IQR of 2 guests (Q1=2, Q3=4) is relatively narrow, confirming that the central 50% of listings accommodate between 2 and 4 guests - a tight cluster despite the wide overall range.
#
# The histogram reveals a multimodal distribution with distinct peaks at 2, 4, and 6 guests. This is not a simple right-skewed distribution - instead, counts spike at even numbers (2, 4, 6, 8) and dip at odd numbers (3, 5, 7), creating a sawtooth pattern. This reflects the practical reality that most properties are designed for couples (2), families of 4, or groups of 6, making even-numbered capacities far more common than odd. Beyond 8 guests, counts drop sharply with a long right tail extending to 16.
#
# The concentration of listings at 2 and 4 guests aligns with the dominance of Entire home/apt and Private room types observed in the room type analysis - most Brisbane Airbnb listings cater to couples or small families. The sawtooth pattern at even numbers is a practically meaningful finding that reflects how hosts configure their properties. The small number of listings accommodating more than 10 guests represent a niche high-capacity segment within the Brisbane Airbnb market. Their relatively low frequency suggests that demand is primarily concentrated among couples, solo travellers, and small families rather than large groups.

# %%
# Histogram for Accomodates
plt.figure(figsize=(8,5))
sns.histplot(train_df['accommodates'], bins=15, color='#4393C3')
plt.title('Distribution of Accommodates')
plt.xlabel('Number of Guests')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **8. Bathrooms**
#
# The mean number of bathrooms is 1.42, the median is 1, and the mode is also 1 - with approximately 2,350 listings having exactly 1 bathroom. The mean being slightly higher than the median indicates a modest right skew caused by a small number of properties with many bathrooms pulling the average upward.
#
# The standard deviation of 0.71 is relatively low compared to other variables, indicating that most listings cluster tightly around 1-2 bathrooms. The range spans from 0 to 9 bathrooms, though values above 4 are extremely rare. The IQR of 1 bathroom (Q1=1, Q3=2) confirms that 75% of all listings have either 1 or 2 bathrooms - very little variability in the central distribution despite the wide overall range.
#
# The histogram shows a strongly right-skewed distribution with a dominant peak at 1 bathroom (~2,350 listings), a secondary peak at 2 bathrooms (~900 listings), and then a rapid drop-off beyond 2. The count at 1.5 bathrooms (representing half-baths or shared bathrooms) is visible as a small bar between the two main peaks. Beyond 3 bathrooms, listings become increasingly rare, with very few properties having 5 or more bathrooms. The long right tail extending to 9 represents a small number of large luxury properties.
#
# The overwhelming concentration at 1 bathroom is consistent with the dominance of small to medium-sized Airbnb listings (studios, 1-2 bedroom apartments) in Brisbane. The secondary peak at 2 bathrooms corresponds to larger family homes and entire rental units that can accommodate 4+ guests. The small number of listings with 3 or more bathrooms likely represents larger family homes, luxury properties, or accommodation designed for larger groups of guests. Overall, the distribution suggests that most Airbnb listings in Brisbane are relatively compact residential properties, while large multi-bathroom properties occupy only a small niche segment of the market.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))

# Left: Original distribution
plot_data = train_df[train_df['bathrooms'].notna()]
sns.histplot(data=plot_data, x='bathrooms', bins=15, color='#4393C3', ax=ax1)
ax1.axvline(plot_data['bathrooms'].mean(),
            color='#B2182B', linestyle='--', linewidth=1.5,
            label=f"Mean: {plot_data['bathrooms'].mean():.2f}")
ax1.axvline(plot_data['bathrooms'].median(),
            color='#2166AC', linestyle='--', linewidth=1.5,
            label=f"Median: {plot_data['bathrooms'].median():.2f}")
ax1.set_title('Distribution of Bathrooms')
ax1.set_xlabel('Number of Bathrooms')
ax1.set_ylabel('Count of units')
ax1.legend()

# Right: Log transformed (log1p vì min = 0)
log_bathrooms = np.log1p(plot_data['bathrooms'])
sns.histplot(log_bathrooms, bins=15, color='#D6604D', ax=ax2)
ax2.axvline(log_bathrooms.mean(),
            color='#B2182B', linestyle='--', linewidth=1.5,
            label=f"Mean: {log_bathrooms.mean():.2f}")
ax2.axvline(log_bathrooms.median(),
            color='#2166AC', linestyle='--', linewidth=1.5,
            label=f"Median: {log_bathrooms.median():.2f}")
ax2.set_title('Log Distribution of Bathrooms')
ax2.set_xlabel('log(Bathrooms + 1)')
ax2.set_ylabel('Count of units')
ax2.legend()

plt.tight_layout()

# %% [markdown]
# **9. Review Scores Rating**
#
# The mean review score is 4.74 and the median is 4.83, both falling very close to the maximum possible score of 5.0. Notably, the median is higher than the mean, indicating a left-skewed distribution where a small number of poorly rated listings pull the average downward. The highest concentration of observations occurs within the 4.9-5.0 range, where approximately 1,430 listings achieve near-perfect ratings.
#
# The standard deviation of 0.37 is extremely low relative to the scale of 1-5, indicating that the vast majority of listings cluster tightly in the upper range. The range spans from 1.0 to 5.0, but this full range is misleading - the IQR of just 0.28 (Q1=4.67, Q3=4.95) reveals that the central 50% of listings are compressed into a very narrow band near the top of the scale. The variance of 0.14 is the smallest of all numerical variables analysed, confirming minimal spread.
#
# The histogram shows a strongly left-skewed (negatively skewed) distribution - the opposite of most other variables in this dataset. Counts are near zero below 3.5, then rise sharply from 4.0 onward, peaking dramatically at 4.9-5.0. This creates a distribution heavily concentrated at the upper end of the scale, with a long but very sparse left tail extending down to 1.0. Very few listings score below 3.0, and those that do are likely outliers representing problematic or one-time poorly reviewed listings.
#
# The strong left skew and concentration of ratings near 5.0 reflects a well-documented phenomenon known as rating inflation, which is common on peer-to-peer platforms. Guests tend to provide highly positive ratings unless they experience significant dissatisfaction, resulting in a distribution heavily concentrated at the upper end of the scale. The narrow spread of ratings suggests that most Airbnb listings in Brisbane are perceived positively by guests, while poorly rated properties represent only a very small proportion of the market. Overall, the distribution indicates consistently high levels of guest satisfaction across the platform.

# %%
# Histogram for Review Score Rating
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

# Left: Original distribution
plot_data = train_df[train_df['review_scores_rating'].notna()]
sns.histplot(plot_data['review_scores_rating'], bins=30,
             color='#4393C3', ax=axes[0])
axes[0].axvline(plot_data['review_scores_rating'].mean(),
                color='#B2182B', linestyle='--', linewidth=1.5,
                label=f"Mean: {plot_data['review_scores_rating'].mean():.2f}")
axes[0].axvline(plot_data['review_scores_rating'].median(),
                color='#2166AC', linestyle='--', linewidth=1.5,
                label=f"Median: {plot_data['review_scores_rating'].median():.2f}")
axes[0].set_title('Distribution of Review Scores Rating')
axes[0].set_xlabel('Review Score')
axes[0].set_ylabel('Count of units')
axes[0].legend()

# Right: Zoomed in (4.0 - 5.0) để thấy rõ phân phối chính
sns.histplot(plot_data['review_scores_rating'], bins=30,
             color='#D6604D', ax=axes[1])
axes[1].axvline(plot_data['review_scores_rating'].mean(),
                color='#B2182B', linestyle='--', linewidth=1.5,
                label=f"Mean: {plot_data['review_scores_rating'].mean():.2f}")
axes[1].axvline(plot_data['review_scores_rating'].median(),
                color='#2166AC', linestyle='--', linewidth=1.5,
                label=f"Median: {plot_data['review_scores_rating'].median():.2f}")
axes[1].set_title('Distribution of Review Scores Rating (Zoomed)')
axes[1].set_xlabel('Review Score')
axes[1].set_ylabel('Count of units')
axes[1].set_xlim(4.0, 5.0)
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **10. Host Listings Count**
#
# The mean host listings count is 50.07, while the median is only 5 and the mode falls in the lowest bin (1-25 listings). The enormous gap between mean (50.07) and median (5) - a ratio of 10:1 - is one of the most extreme disparities observed across all variables in this dataset, indicating that a very small number of hosts with hundreds of listings are dramatically inflating the average.
#
# The standard deviation of 111.88 is more than twice the mean, reflecting extraordinary variability. The range spans from 1 to 702 listings - an almost 700-fold difference between the smallest and largest host portfolios. The IQR of 31 listings (Q1=1, Q3=32) confirms that 75% of hosts manage fewer than 32 listings, while the upper 25% includes hosts ranging from 32 to 702 listings. This extreme spread highlights the coexistence of two fundamentally different types of market participants.
#
# The vast majority of observations are concentrated among hosts managing relatively small numbers of listings, with counts declining sharply as portfolio size increases. Small local peaks are visible at higher portfolio sizes, suggesting the presence of clusters of hosts managing large numbers of listings. The tail extends all the way to 702, representing a single host managing over 700 listings - a clear outlier in the context of typical Airbnb hosting.
#
# The extreme right skew and the large gap between the mean and median reveal a highly concentrated market structure within Brisbane’s Airbnb ecosystem. Most hosts manage only a small number of listings, suggesting that individual or small-scale operators dominate the market. However, a small number of hosts manage very large portfolios, indicating the presence of commercial operators alongside casual hosts. This distribution highlights the coexistence of different hosting models and varying levels of market participation within Brisbane’s short-term rental sector.

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

# Left: Original distribution
plot_data = train_df[train_df['host_listings_count'].notna()]
sns.histplot(plot_data['host_listings_count'], bins=30,
             color='#4393C3', ax=axes[0])
axes[0].axvline(plot_data['host_listings_count'].mean(),
                color='#B2182B', linestyle='--', linewidth=1.5,
                label=f"Mean: {plot_data['host_listings_count'].mean():.2f}")
axes[0].axvline(plot_data['host_listings_count'].median(),
                color='#2166AC', linestyle='--', linewidth=1.5,
                label=f"Median: {plot_data['host_listings_count'].median():.2f}")
axes[0].set_title('Distribution of Host Listings Count')
axes[0].set_xlabel('Number of Listings Owned by Host')
axes[0].set_ylabel('Count of units')
axes[0].legend()

# Right: Log transformed
log_host = np.log(plot_data['host_listings_count'])
sns.histplot(log_host, bins=30,
             color='#D6604D', ax=axes[1])
axes[1].axvline(log_host.mean(),
                color='#B2182B', linestyle='--', linewidth=1.5,
                label=f"Mean: {log_host.mean():.2f}")
axes[1].axvline(log_host.median(),
                color='#2166AC', linestyle='--', linewidth=1.5,
                label=f"Median: {log_host.median():.2f}")
axes[1].set_title('Log Distribution of Host Listings Count')
axes[1].set_xlabel('log(Number of Listings Owned by Host)')
axes[1].set_ylabel('Count of units')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **11. Property Type**
#
# Property type is a categorical variable, so the mode is the appropriate measure of central tendency. The mode is Entire rental unit, which accounts for 54.2% of all listings - more than half the entire dataset on its own.
#
# - Entire rental unit:        54.2%
# - Entire home:               17.9%
# - Private room in home:      15.4%
# - Private room in rental unit: 5.9%
# - Entire guest suite:         3.7%
# - Entire serviced apartment:  2.9%
#
# The distribution is heavily concentrated in the top two categories - Entire rental unit (54.2%) and Entire home (17.9%) together account for 72.1% of all listings. The remaining four categories collectively make up only 27.9%, with each contributing less than 16%. This extreme concentration indicates very low diversity in property type, with the market dominated by one clear category.
#
# The pie chart shows a highly imbalanced distribution - Entire rental unit dominates with more than half the market share, while Entire serviced apartments (2.9%) and Entire guest suites (3.7%) represent relatively small segments of the market. The sharp drop from 54.2% to 17.9% between the top two categories confirms the dominance of rental units in Brisbane's Airbnb market.
#
# The dominance of Entire rental units (54.2%) reflects Brisbane’s urban housing landscape, where apartment-style accommodation forms a major component of the Airbnb market. Entire homes represent a substantial secondary segment and are likely associated with suburban residential areas, while private rooms reflect the traditional sharing-economy model where hosts rent spare rooms within occupied properties. The relatively small proportions of guest suites and serviced apartments indicate that these property types occupy niche positions within the Brisbane Airbnb market. Overall, the distribution suggests that independent accommodation is strongly preferred over shared living arrangements.

# %%
# Pie char for categorical Property Type
property_counts = train_df['property_type'].value_counts().head(6)
rdbu_colors = ['#2166AC', '#4393C3', '#92C5DE', '#F4A582', '#D6604D', '#B2182B']

plt.figure(figsize=(7,7))
plt.pie(property_counts,
        labels=property_counts.index,
        colors=rdbu_colors,
        autopct='%1.1f%%')
plt.title('Property Type Distribution')
plt.show()

# %% [markdown]
# **CONCLUSION**
#
# The univariate analysis reveals several important patterns within the Brisbane Airbnb dataset. Numerical variables such as price, minimum_nights, number_of_reviews, and host_listings_count exhibit strong positive skewness and contain extreme values, indicating substantial heterogeneity across listings and hosts. In contrast, review_scores_rating is negatively skewed and tightly concentrated near the maximum rating, reflecting consistently high levels of guest satisfaction. The availability_365 variable displays a distinctive bimodal distribution, suggesting the presence of different hosting strategies within the market. The categorical variables show that Airbnb activity is concentrated in inner-city neighbourhoods and is dominated by entire-property accommodation. Overall, these findings provide valuable insights into the structure, diversity, and characteristics of Brisbane’s Airbnb market.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 5. Feature Analysis and Selection (2 marks)
# Select at least 20 meaningful features from the dataset.
#
# - Categorise each feature according to its variable type and present the results in a table (similar to Assignment 1)
# - Analyse how key features relate to the target variable (*price*) using appropriate plots and/or summary statistics
# - Justify your feature selection based on your analysis
# ---

# %% [markdown]
# **Table 1. Classification of Selected Original Features**
#
# | Variable Type | Number of Features | Feature Names |
# | --- | --- | --- |
# | Numerical (continuous) | 13 | `bathrooms`, `estimated_occupancy_l365d`, `review_scores_rating`, `review_scores_accuracy`, `review_scores_cleanliness`, `review_scores_checkin`, `review_scores_communication`, `review_scores_location`, `review_scores_value`, `reviews_per_month`, `calculated_host_listings_count`, `latitude`, `longitude` |
# | Numerical (discrete) | 11 | `accommodates`, `bedrooms`, `beds`, `minimum_nights`, `maximum_nights`, `availability_30`, `availability_365`, `number_of_reviews`, `number_of_reviews_ltm`, `number_of_reviews_l30d`, `host_listings_count` |
# | Categorical (nominal) | 6 | `room_type`, `property_type`, `neighbourhood_cleansed`, `amenities`, `host_response_time`, `name` |
# | Categorical (ordinal) | 1 | `host_response_time` `
# | Boolean | 3 | `host_is_superhost`, `instant_bookable`, `host_identity_verified` |
# | Date | 2 | `host_since`, `last_review` |

# %%
# Define desired features here
# Continuous features
num_features = [
   'bathrooms', 'estimated_occupancy_l365d', 'review_scores_rating', 'review_scores_accuracy',
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value',
    'reviews_per_month', 'calculated_host_listings_count', 'latitude', 'longitude',
    'accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'availability_30', 'availability_365',
    'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'host_listings_count'
    
]
# Categorical features
cat_features  = ['room_type', 'property_type', 'neighbourhood_cleansed','amentities', 'host_response _time', 'name']
# Boolean features
bool_features = ['host_is_superhost', 'instant_bookable', 'host_identity_verified']
# Date features 
date_features = ['host_since', 'last_review']

# %% [markdown]
# **Table 2. Classification of Final Features Used for Modelling**
#
# | Variable Type | Count | Feature Names |
# |--------------|-------|--------------|
# | Numerical (continuous) | 19 | `bathrooms`, `estimated_occupancy_l365d`, `review_scores_rating`, `review_scores_accuracy`, `review_scores_cleanliness`, `review_scores_checkin`, `review_scores_communication`, `review_scores_location`, `review_scores_value`, `reviews_per_month`, `calculated_host_listings_count`, `amenities_count`, `host_experience_days`, `days_since_last_review`, `beds_per_person`, `bath_to_bedroom_ratio`, `accommodates_per_bedroom`, `availability_rate`, `dist_to_cbd` |
# | Numerical (discrete) | 10 | `accommodates`, `bedrooms`, `beds`, `minimum_nights`, `maximum_nights`, `availability_30`, `availability_365`, `number_of_reviews`, `number_of_reviews_ltm`, `number_of_reviews_l30d` |
# | Categorical (nominal) | 5 | `room_type`, `property_type`, `neighbourhood_cleansed`, `amenities`, `host_response_time` |
# | Categorical (ordinal) | 1 | `host_response_time` |
# | Boolean | 38 | `host_is_superhost`, `instant_bookable`, `host_identity_verified`, `is_commercial_host`, (from _amenities_ bucket): `has_wifi`, `has_smoke_alarm`, `has_kitchen`, `has_washer`, `has_tv`, `has_hot_water`, `has_hangers`, `has_refrigerator`, `has_air_conditioning`, `has_hair_dryer`, `has_iron`, `has_free_parking`, `has_hot_water_kettle`, `has_essentials`, `has_self_checkin`, `has_heating`, `has_dryer`, `has_workspace`, `has_pool`, `has_fire_extinguisher`, `has_first_aid_kit`, `has_coffee_maker`, `has_gym`, `has_paid_parking`, `has_pets_allowed`, `name_luxury`, `name_pool`, `name_view`, `name_studio`, `name_cbd`, `name_beach`, `name_ocean`, `name_penthouse`, `name_modern` |
# | Engineered | 42 | `amenities_count` (from `amenities`), `host_experience_days` (from `host_since`), `days_since_last_review` (from`last_review`), `is_commercial_host` (from `host_listing_count`), `beds_per_person` (from `beds` and `accommodates`), `bath_to_bedroom_ratio` (from `bathrooms` and `bedrooms`), `accommodates_per_bedroom` (from `accommodates` and `bedrooms`), `availability_rate` (from `availability365`),  `dist_to_cbd` (from `latitude` and `longitude`); `has_wifi`, `has_smoke_alarm`, `has_kitchen`, `has_washer`, `has_tv`, `has_hot_water`, `has_hangers`, `has_refrigerator`, `has_air_conditioning`, `has_hair_dryer`, `has_iron`, `has_free_parking`, `has_hot_water_kettle`, `has_essentials`, `has_self_checkin`, `has_heating`, `has_dryer`, `has_workspace`, `has_pool`, `has_fire_extinguisher`, `has_first_aid_kit`, `has_coffee_maker`, `has_gym`, `has_paid_parking`, `has_pets_allowed` (from `amanity`); `name_luxury`, `name_pool`, `name_view`, `name_studio`, `name_cbd`,  `name_beach`, `name_ocean`, `name_penthouse`, `name_modern` (from `name`) |

# %% [markdown]
# **Before selecting meaningful features, variables that provide little or no predictive value were removed.**
#
# - Identifier and Personal Information Variables (`ID`, `host_id`, `host_name`):
#
# Were removed because they function primarily as identifiers rather than meaningful property characteristics. These variables do not provide information about listing quality, location, capacity, or host behaviour and therefore are unlikely to contribute useful predictive information.
#
# - Free-text Variables (`description`, `neighborhood_overview`, `host_about`):
#
# Were excluded because they contain unstructured textual information that would require natural language processing techniques to extract meaningful signals. Since the focus of this project is on structured data modelling, these variables were not considered further.
#
# - Location-related Variables (`host_location`, `host_neighbourhood`):
#
# Were removed due to inconsistent formatting, substantial missingness, and overlap with neighbourhood_cleansed, which provides a cleaner and more standardised representation of listing location.
#
# - Administrative and Platform Metadata Variables (`source`, `host_verifications`):
#
# Were excluded because they primarily contain platform-level information rather than direct property characteristics. In addition, host_verifications consists of complex multi-category text values that would require additional feature engineering before being suitable for modelling.
#
# - Duplicate information column (`bathrooms_text`):
#
# This variable contains a textual representation of the number of bathrooms (e.g., "1 bath", "2 baths"), which duplicates the information already captured in the numerical `bathrooms` variable. Since the numeric version is more suitable for statistical analysis and modelling, `bathrooms_text` was excluded to avoid redundancy.
#
# - Revenue Variable (`estimated_revenue_l365d`):
#
# `estimated_revenue_l365d` is removed due to concerns regarding **target leakage**. This variable is calculated using listing price, which is the target variable that the model is trying to predict. As a result, information from the target is already embedded within the feature itself. If `estimated_revenue_l365d` were included in the model, the model could partially infer the value of `price` from a variable that was directly derived from it, rather than learning genuine relationships between price and listing characteristics such as location, property type, capacity, and host behaviour. Consequently, the model's performance may appear better than it actually is, as it is effectively being given access to information related to the answer. In contrast, `estimated_occupancy_l365d` was retained because it captures booking demand without directly incorporating the target variable.

# %%
# Remove text/descriptive columns that add no signal
# NOTE: 'name' is kept here — keyword flags are extracted from it in the feature engineering step
features_to_drop = [
    'description', 'neighborhood_overview', 'host_name', 'host_id',
    'host_about', 'host_location', 'host_neighbourhood', 'host_verifications',
    'bathrooms_text'
]
train_data = raw_train_df.drop(columns=[c for c in features_to_drop if c in raw_train_df.columns])
test_data  = raw_test_df.drop( columns=[c for c in features_to_drop if c in raw_test_df.columns])

# %%
print(train_data['estimated_revenue_l365d'].describe())
print(f"\nMissing: {train_data['estimated_revenue_l365d'].isnull().sum()}")
print(f"Min: {train_data['estimated_revenue_l365d'].min()}")
print(f"Max: {train_data['estimated_revenue_l365d'].max()}")
# Out:
# count      3735.000000
# mean      19195.382329
# std       24953.948212
# min           0.000000
# 25%        2280.000000
# 50%       10962.000000
# 75%       28560.000000
# max      426615.000000
# Name: estimated_revenue_l365d, dtype: float64
#
# Missing: 0
# Min: 0.0
# Max: 426615.0

# %%
# Check statistically numeric features of desire
train_data[num_features].describe()
# Out:
#          bathrooms  estimated_occupancy_l365d  review_scores_rating  \
# count  3730.000000                3735.000000            3298.00000
# mean      1.424129                  91.639893               4.74248
# std       0.705594                  87.603878               0.36693
# min       0.000000                   0.000000               1.00000
# 25%       1.000000                  12.000000               4.67000
# 50%       1.000000                  66.000000               4.83000
# 75%       2.000000                 156.000000               4.95000
# max       9.000000                 255.000000               5.00000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             3298.000000                3298.000000
# mean                 4.782016                   4.725891
# std                  0.346275                   0.363493
# min                  1.000000                   1.000000
# 25%                  4.720000                   4.640000
# ...

# %% [markdown]
# #### The relationship between features and price
#
# **1. Numerical analysis**
#
# **a. Heatmap using Pearson method**

# %%
# Price has "$" and "," and it is a object -> need to remove the signs & change to float
train_data['price_original'] = train_data['price']

# Create a cleaned version for analysis
train_data['price_clean'] = (
    train_data['price']
    .str.replace(r'[$,]', '', regex=True)
    .astype(float)
)

print(train_data[['price_original', 'price_clean']].head())
# Out:
#   price_original  price_clean
# 0         $97.00         97.0
# 1        $205.00        205.0
# 2        $186.00        186.0
# 3        $157.00        157.0
# 4        $300.00        300.0

# %%
features = train_data[num_features]
fea = pd.get_dummies(features)

fea['price'] = train_data['price_clean']

corr = fea.corr(method='pearson')

corr_no_diag = corr.copy()
np.fill_diagonal(corr_no_diag.values, 0)

price_corr = corr_no_diag['price'].abs() > 0.05
filtered_cols = price_corr[price_corr].index.tolist()

if 'price' not in filtered_cols:
    filtered_cols.append('price')

corr_filtered = corr.loc[filtered_cols, filtered_cols]

mask = np.zeros_like(corr_filtered, dtype=np.bool_)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 18))

sns.heatmap(
    corr_filtered,
    annot=True,
    mask=mask,
    center=0,
    square=True,
    cmap='RdBu',
    xticklabels='auto',
)

plt.title('Correlation between the variables of train dataset')
# Out:
# Text(0.5, 1.0, 'Correlation between the variables of train dataset')

# %% [markdown]
# **Numerical Feature Analysis - Correlation with Price**
#
# - Pearson correlation was used to measure the linear relationship between each numerical feature and price. Only features with
# |correlation| > 0.05 with price are retained in the heatmap to reduce visual noise.
#
# **Must-select features (|corr| > 0.2):**
#
# - Must-selected(abs(corr)>0.2):  `accommodates`, `bathrooms`, `bedrooms`, `beds`
# - These physical capacity variables show the clearest positive relationship with price — listings that can accommodate more guests, with more bedrooms and bathrooms, consistently command higher nightly rates. This is intuitive: larger properties require more infrastructure and offer more value to guests, justifying premium pricing.
#
# **Consider features (|corr| > 0.1):**
#
# - Consider (abs(corr)>0.1): `maximum_nights`, `availability_30`, `number_of_reviews_ltm`, `estimated_occupancy_l365d`.
# - Although their individual correlations are considerably lower than those of the capacity-related variables, they capture aspects of listing availability, booking activity, and occupancy patterns that may provide additional predictive value when considered alongside other features.
#
#
# **Other observations from the heatmap:**
#
# - Several features show high inter-correlation with each other
# rather than with price:
#
#     **Availability**
#
#     - These variables are highly correlated with one another (0.90-0.99), indicating substantial redundancy. Among the availability measures, `availability_30` was retained because it exhibits the strongest relationship with price while capturing short-term availability behaviour.
#
#     **Caculated host listing**
#
#     - These variable, ex: `calculated_host_listings_count_private_rooms`, shows only a weak negative correlation with price (-0.074). Although it was retained in the heatmap under the |corr| > 0.05 screening threshold, the relationship is too weak to justify prioritising it as a key predictor of price -> not included.
#
#     **Review bucket**
#
#     - `number_of_reviews` and `reviews_per_month` both exhibit weak negative correlations with price (|corr| < 0.1). Although their direct linear relationships with price are limited, these variables provide useful information about listing popularity, activity, and market demand. Therefore, they were retained for further consideration despite their relatively low correlation coefficients.
#
# - A low Pearson correlation with price does not necessarily mean a feature should be excluded because there are some non-linear relationship between them.
#
#     **Review Score**
#
#     - Features such as `review_scores_cleanliness`, `review_scores_location` and `estimated_occupancy_l365d` show weak linear correlations but may still capture non-linear relationships with price or provide useful information when combined with other predictors. Therefore, both statistical evidence and domain knowledge were considered when selecting the final set of features.

# %% [markdown]
# A scatterplot matrix was constructed using the selected numerical features to further explore relationships among predictors and identify potential multicollinearity.
#
# - **Size features are strongly correlated** — `accommodates`, `bedrooms`, `bathrooms`, and `beds` rise together
#
# - **Occupancy drives reviews** — a positive association between `number_of_reviews_ltm` and `estimated_occupancy_l365d` shows that higher-occupancy listings tend to collect more reviews
#
# - **Availability and limits are weak, dispersed predictors** — `availability_30` and `maximum_nights` show weaker, scattered relationships with price and the other features.
#
# Overall, the scatterplot matrix supports the findings from the correlation analysis while providing additional insight into relationships among the predictors themselves. Even though no clear linear pattern, they reflect host availability and booking restrictions that may still influence pricing and booking performance.

# %%
# Scatter plox - finding relationship between price and key features
key_features = ['price_clean', 'accommodates', 'bedrooms', 'bathrooms', 'beds',
                'availability_30', 'maximum_nights',  'number_of_reviews_ltm', 'estimated_occupancy_l365d']

plot_data = train_data[key_features].dropna()

sns.pairplot(plot_data,
             diag_kind='hist',
             plot_kws={'alpha': 0.3, 's': 10, 'color': '#4393C3'},
             diag_kws={'color': '#4393C3'},
             height=2)

plt.suptitle('Scatterplot Matrix — Key Features vs Price',
             y=1.02, fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# **c. Scatterplots of Top Predictors**
#
# To further evaluate the most influential numerical features identified in the correlation analysis, scatterplots were constructed for `accommodates`, `bedrooms`, `bathrooms`, and `beds`. These variables were selected for closer examination because they exhibited the strongest positive correlations with price and directly represent property size and guest capacity.
#
# - Across all four plots, a clear positive association with price can be observed.
# - This pattern is consistent with expectations, as larger properties typically offer greater space, comfort, and functionality, allowing hosts to command premium prices.
#
# - Substantial variation remains within each category. For example, listings with the same number of bedrooms or guest capacity can still differ considerably in price.
# - This suggests that other factors such as location, property type, amenities, and host characteristics also contribute to pricing decisions.
#
# - Several high-priced outliers are also visible, particularly among larger properties with greater capacities and more rooms. These observations likely represent premium or luxury listings and further reinforce the relationship between property size and higher prices.

# %%
# Top 4 scatter plot
top4 = price_corr.abs().nlargest(4).index.tolist()

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
for ax, feat in zip(axes.flatten(), top4):
    sns.scatterplot(data=train_data, x=feat, y='price_clean', alpha=0.25,
                    color='#4393C3', ax=ax)
    ax.set_title(f'{feat}')
    ax.set_xlabel(feat)
    ax.set_ylabel('Price (AUD)')
plt.suptitle('The Relationship Between Top 4 Numerical Features vs Price', y=1.01, fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Categorical Feature Analysis**
#
# > Box plots were used to examine how categorical features relate to price, with median price used as the central measure due to the right-skewed distribution of price observed in Question 4.

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 14))

# Room type
order_rt = train_data.groupby('room_type')['price_clean'].median().sort_values(ascending=False).index
sns.boxplot(data=train_data, x='price_clean', y='room_type', order=order_rt,
            hue='room_type', palette='RdBu', legend=False,
            showfliers=False, ax=axes[0, 0])
axes[0, 0].set_title('Price by Room Type')
axes[0, 0].set_xlabel('Price (AUD)')
axes[0, 0].set_ylabel('')

# Property type
top20_prop = train_data['property_type'].value_counts().nlargest(20).index
prop_data  = train_data[train_data['property_type'].isin(top20_prop)]
order_prop = prop_data.groupby('property_type')['price_clean'].median().sort_values(ascending=False).index
sns.boxplot(data=prop_data, x='price_clean', y='property_type', order=order_prop,
            hue='property_type', palette='RdBu', legend=False,
            showfliers=False, ax=axes[0, 1])
axes[0, 1].set_title('Price by Property Type (Top 20)')
axes[0, 1].set_xlabel('Price (AUD)')
axes[0, 1].set_ylabel('')

# Neighbourhood
top20_neigh = train_data['neighbourhood_cleansed'].value_counts().nlargest(20).index
neigh_data  = train_data[train_data['neighbourhood_cleansed'].isin(top20_neigh)]
order_neigh = neigh_data.groupby('neighbourhood_cleansed')['price_clean'].median().sort_values(ascending=False).index
sns.boxplot(data=neigh_data, x='price_clean', y='neighbourhood_cleansed', order=order_neigh,
            hue='neighbourhood_cleansed', palette='RdBu', legend=False,
            showfliers=False, ax=axes[1, 0])
axes[1, 0].set_title('Price by Neighbourhood (Top 20 by Listing Count)')
axes[1, 0].set_xlabel('Price (AUD)')
axes[1, 0].set_ylabel('')

# Host response time
rt_order = ['within an hour', 'within a few hours', 'within a day', 'a few days or more']
rt_data  = train_data.dropna(subset=['host_response_time'])
sns.boxplot(data=rt_data, x='price_clean', y='host_response_time', order=rt_order,
            hue='host_response_time', palette='RdBu', legend=False,
            showfliers=False, ax=axes[1, 1])
axes[1, 1].set_title('Price by Host Response Time')
axes[1, 1].set_xlabel('Price (AUD)')
axes[1, 1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# - _Room type_:
#
#  Clear price ranking by privacy/exclusivity: Hotel rooms highest (~$350 median), then Entire home/apt (~$220), Private rooms (~$100), and Shared rooms (~$60). Hotel and entire-home listings show wider spread and long upper tails (standard + premium offerings); private/shared rooms are more concentrated. Retained as a key categorical feature.
#
# - _Property type_
#
#  Premium formats (Entire villa, Room in hotel, Entire serviced apartment) exceed ~$300 median, while private-room variants sit below $100. Entire-property listings have wider, more heterogeneous distributions; private rooms are narrower and budget-oriented. Captures variation beyond `room_type`, so retained.
#
# - _Neighbourhood_
#
#  Location matters: inner-city areas (Brisbane City, New Farm, Hamilton, Paddington-Milton) have higher medians; outer suburbs (Sunnybank, Sunnybank Hills, East Brisbane) lower. Inner-city areas show wider spread (mix of standard and premium); cheaper suburbs are more homogeneous. Reflects proximity to CBD, transport, and attractions — `neighbourhood_cleansed` retained.
#
# - _Host response time_
#
#  Medians and IQRs are broadly similar across all categories, so response time alone is a weak price predictor. Retained anyway, as it may add value in combination with other host/listing features.
#
# - _Amenities_
#
#  Not visualised (raw list-format text). Will be feature-engineered in Task 2 into `amenities_count` as a proxy for listing quality, expected to relate positively to price.

# %% [markdown]
# **3. Boolean Feature Analysis**
#
# > Three boolean features were examined using box plots to assess their relationship with price.

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 5))

for ax, col, title in zip(
    axes, bool_features, ['Superhost Status', 'Instant Bookable', 'Identity Verified']
):
    plot_data = train_data.dropna(subset=[col]).copy()
    plot_data[col] = plot_data[col].map({'t': 'Yes', 'f': 'No'})
    sns.boxplot(data=plot_data, x=col, y='price_clean', showfliers=False,
                hue=col, palette=['#2166AC', '#B2182B'], legend=False, ax=ax)
    ax.set_title(f'Price by {title}')
    ax.set_xlabel('')
    ax.set_ylabel('Price (AUD)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - _Superhost Status_
#
# Median price barely differs between Superhost and non-Superhost listings, with almost fully overlapping IQRs. Weak direct relationship, but `host_is_superhost` is retained as a proxy for host experience, reliability, and service quality.
#
# - _Instant Bookable_
#
# Small median-price difference with substantial overlap, so `instant_bookable` is only weakly associated with price. Retained because it captures booking flexibility and host preferences that may shape booking behaviour.
#
# - _Identity Verified_
#
# All three boolean features show weak individual links to price, but each reflects a different aspect of host quality, credibility, or booking behaviour not captured by physical property traits — so all three were retained for modelling.
#
# Overall, the three boolean features exhibit relatively weak individual relationships with price. However, they capture different aspects of host quality, credibility, and booking behaviour that are not reflected by physical property characteristics alone. For this reason, all three features were retained for subsequent modelling despite their limited standalone predictive strength.

# %% [markdown]
# **d. The remaining variables**

# %%
train_data['host_response_rate_num'] = (
    train_data['host_response_rate']
    .str.replace('%', '')
    .astype(float)
)

train_data['host_acceptance_rate_num'] = (
    train_data['host_acceptance_rate']
    .str.replace('%', '')
    .astype(float)
)

cols = [
    'host_response_rate_num',
    'host_acceptance_rate_num',
    'host_listings_count',
    'review_scores_rating',
    'review_scores_accuracy',
    'review_scores_checkin',
    'review_scores_value',
    'review_scores_communication',
    'minimum_nights',
    'number_of_reviews'
]

for col in cols:
    print(col, train_data['price_clean'].corr(train_data[col]))
# Out:
# host_response_rate_num -0.08288466135244607
# host_acceptance_rate_num -0.09046667465899677
# host_listings_count 0.08193769983530433
# review_scores_rating 0.04975361544327901
# review_scores_accuracy 0.03240047010212609
# review_scores_checkin -0.003072699111980201
# review_scores_value -0.008516669152640401
# review_scores_communication 0.012249263464392677
# minimum_nights 0.0058881344136950675
# number_of_reviews -0.08195712837093448

# %% [markdown]
# - _Host behaviour metrics_
#
# `host_response_rate`, `host_acceptance_rate`, and `host_listings_count` all correlate weakly with price (|corr| < 0.1). Host behaviour alone doesn't determine price, but they capture host reliability, experience, and business activity and may add value alongside other features — so retained.
#
# - _Review scores_
#
# `review_scores_rating`, `accuracy`, `checkin`, `value`, and `communication` show only weak linear ties to price. guest satisfaction may affect pricing non-linearly (not captured by Pearson), and each reflects a different quality/experience dimension — so retained.
#
# - _Minimum nights_
#
# Very weak correlation (0.006) but retained on domain grounds, as it represents a key booking policy; selection balanced statistics with domain relevance.
#
# - _Review counts_
#
# Weak correlation, but the three capture different demand signals: `number_of_reviews` (long-term popularity) vs `number_of_reviews_ltm` / `number_of_reviews_l30d` (recent activity). All three kept to cover both historical and recent demand.
#
# - **Retained for feature engineering**
#
# `host_since`, `last_review`, `latitude`, `longitude`, `amenities`, and `name` show weak direct links to price in raw form but hold information that can be transformed into stronger predictors in Tasks 2–3, so they were kept for further processing.

# %% [markdown]
# ---- Add your written answer here ------

# %% [markdown]
# ---
# ---
#
# ## Task 2: Data Cleaning, Missing Observations and Feature Engineering
#
# **Total Marks: 10**
#
# - Use the features selected in **Task 1, Question 5** for this task.
# - Ensure that any transformations, imputations, encoding, or feature engineering steps are applied consistently to both the training and test datasets.
# - Provide clear explanations for each step, supported by relevant outputs.

# %% [markdown]
# Student in charge of this task: `Dieu Linh Ngo`
#
# <hr style="width:25%;margin-left:0;">

# %% [markdown]
# #### 1. Numerical Data Cleaning (2 marks)
#
# Clean all numerical features so that they are suitable for use in training algorithms.
# - Extract numerical values from text-based fields where necessary
# - Remove non-numeric characters %, $, commas, etc.
# - Briefly describe the steps you take

# %%
train_data['price'] = (train_data['price'].str.replace('$', '', regex=False)
                               .str.replace(',', '', regex=False)
                               .astype(float))

# Remove non-numeric characters and cast to float — applied to BOTH train and test
for df in [train_data, test_data]:
    df['host_response_rate']  = (df['host_response_rate'].str.replace('%', '', regex=False)
                                                          .astype(float))
    df['host_acceptance_rate'] = (df['host_acceptance_rate'].str.replace('%', '', regex=False)
                                                             .astype(float))

print("train_data dtypes:")
print(train_data[['price','host_response_rate','host_acceptance_rate']].dtypes)
# Out:
# train_data dtypes:
# price                   float64
# host_response_rate      float64
# host_acceptance_rate    float64
# dtype: object

# %%
train_data.host_response_rate
# Out:
# 0       100.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0
#         ...
# 3730    100.0
# 3731    100.0
# 3732     99.0
# 3733    100.0
# 3734    100.0
# Name: host_response_rate, Length: 3735, dtype: float64

# %%
# Verify all numerical features are numeric types
dtype_report = train_data[num_features].dtypes.to_frame('dtype')
display(dtype_report)
print(f"\nAll {len(num_features)} features confirmed numeric: "
      f"{train_data[num_features].select_dtypes(include='number').shape[1] == len(num_features)}")
# Out:
#                                   dtype
# bathrooms                       float64
# estimated_occupancy_l365d         int64
# review_scores_rating            float64
# review_scores_accuracy          float64
# review_scores_cleanliness       float64
# review_scores_checkin           float64
# review_scores_communication     float64
# review_scores_location          float64
# review_scores_value             float64
# reviews_per_month               float64
# calculated_host_listings_count    int64
# latitude                        float64
# longitude                       float64
# accommodates                      int64
# bedrooms                        float64
# beds                            float64
# minimum_nights                    int64
# maximum_nights                    int64
# availability_30                   int64
# availability_365                  int64
# number_of_reviews                 int64
# number_of_reviews_ltm             int64
# ...

# %% [markdown]
# **Steps of numerical data cleaning:**
#
# - Looking at all the selected numeric features, I notice that there are three text-based features required conversion before modelling: `price`, `host_response_rate`, and `host_acceptance_rate`.
#
#     - `price`: initially stored as a string with leading `$` and comma separators. Both characters were removed and the column was cast to `float64`.
#     - `host_response_rate` and `host_acceptance_rate`: initially stored as percentage strings (e.g: `"97%"`). The `%` symbol was removed and values were cast to `float64`, yielding a numeric scale of 0–100.
#
# - After that, I verify the transformations by printing the dtypes of the three cleaned columns to confirm they are now numeric (float64).
#
# - Finally, I audit all numerical features by generating a dtype report for every column in num_features and programmatically confirming that all of them are numeric types, ensuring no string-encoded values remain before modeling.
#
# All transformations were applied identically to both training and test datasets. The dtype verification confirms that all numerical features are now stored as numeric types, making them suitable for use in scikit-learn estimators.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 2. Feature Engineering (2 marks)
#
# Create at least 4 new features from existing variables that contain multiple pieces of information.
# - Transform existing variables to extract useful information
# - Provide a brief description of how each feature is constructed
# - Briefly justify why each new feature may be useful
#
# I'll create a set of function to engineer the features

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Feature engineering
SNAPSHOT_DATE = pd.Timestamp('2025-12-01')  # after all known scrape dates
CBD_LAT, CBD_LON = -27.4698, 153.0251 #Brisbane CBD


def haversine_cbd(lat, lon):
    R = 6371
    lat1, lon1 = np.radians(lat), np.radians(lon)
    lat2, lon2 = np.radians(CBD_LAT), np.radians(CBD_LON)
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    return R * 2 * np.arcsin(np.sqrt(a))

def safe_ratio(numerator, denominator):
    """
    denominator == 0 ~ NaN (not 1). NaN will be impute later
    """
    denom = denominator.replace(0, np.nan)
    return numerator / denom

def new_features(df):
    # 1. amenities_count: number of amenities 
    am = df['amenities'].fillna('[]')
    df['amenities_count'] = np.where(am == '[]', 0, am.str.count(',') + 1)

    # 2. host_experience_days: days since host joined Airbnb
    host_since = pd.to_datetime(df['host_since'], errors='coerce')
    df['host_experience_days'] = (SNAPSHOT_DATE - host_since).dt.days.clip(lower=0)

    # 3. days_since_last_review: days since last review
    last_review = pd.to_datetime(df['last_review'], errors='coerce')
    df['days_since_last_review'] = (SNAPSHOT_DATE - last_review).dt.days

    # 4. is_commercial_host: 1 if host manages more than 1 listing
    df['is_commercial_host'] = (df['host_listings_count'] > 1).astype(int)

    # 5. beds_per_person: bed-to-guest ratio — proxy for comfort level
    df['beds_per_person'] = safe_ratio(df['beds'], df['accommodates'])

    # 6. bathroom/bedroom: bathrooms per bedroom — proxy for luxury level
    df['bath_to_bedroom_ratio'] = safe_ratio(df['bathrooms'], df['bedrooms'])

    # 7. accommodates_per_bedroom: guest capacity per bedroom — space density proxy
    df['accommodates_per_bedroom'] = safe_ratio(df['accommodates'], df['bedrooms'])

    # 8. availability_rate: proportion of year the listing is available
    df['availability_rate'] = df['availability_365'] / 365

    # 9. dist_to_cbd: Haversine distance (km) from listing to Brisbane CBD
    df['dist_to_cbd'] = haversine_cbd(df['latitude'], df['longitude'])
    
    # 10. Capture the structural 'Zero' state explicitly
    df['is_inactive_host'] = (df['estimated_occupancy_l365d'] == 0).astype(int)
    return df

# apply consistently on both set (explicit reassignment for pandas CoW safety)
train_data = new_features(train_data)
test_data  = new_features(test_data)


# -----step 2: cluster FIT ONLY TRAIN, NOT TEST
# geo_cluster: K-Means spatial cluster (fit on train only to avoid leakage)
_geo_scaler = StandardScaler().fit(train_data[['latitude', 'longitude']])
_kmeans_geo = KMeans(n_clusters=5, random_state=42, n_init=10)
_kmeans_geo.fit(_geo_scaler.transform(train_data[['latitude', 'longitude']]))

for df in [train_data, test_data]:
    labels = _kmeans_geo.predict(_geo_scaler.transform(df[['latitude', 'longitude']]))
    df['geo_cluster'] = ['zone_' + str(l) for l in labels]


# --- Step 3: Drop unnecessary columns and keep only new feature and the rest
DROP_COLS = [
    'availability_365',          # same with availability_rate
    'latitude', 'longitude',     # dist_to_cbd + geo_cluster
    'host_since', 'last_review', 'first review'  # feature engine done
]
for df in [train_data, test_data]:
    df.drop(columns=[c for c in DROP_COLS if c in df.columns], inplace=True)

NEW_FEATURES = [
    'amenities_count', 'host_experience_days', 'days_since_last_review', 'is_commercial_host', 'beds_per_person',
    'bath_to_bedroom_ratio', 'accommodates_per_bedroom', 'availability_rate',
    'dist_to_cbd', 'geo_cluster',
]

# %% [markdown]
# ### **Comments:**
#
# Ten new features were constructed from the raw data to capture additional signal
# not directly available in the original columns. All transformations were applied
# consistently to both the training and test sets. Where a transformation requires
# fitting (e.g. K-Means clustering, StandardScaler), parameters were estimated on
# the training set only and then applied to the test set to prevent data leakage.
#
#
# **1. `amenities_count`**
# - **Construction:** Count the number of commas in the `amenities` JSON string and
#   add 1; assign 0 for empty lists.
# - **Justification:** Listings with more amenities offer greater comfort and
#   convenience, which typically commands a higher price.
#
#
# **2. `host_experience_days`**
# - **Construction:** Number of days elapsed between `host_since` and the snapshot
#   date (2025-12-01), clipped at 0.
# - **Justification:** More experienced hosts understand the market better and tend
#   to price their listings more competitively and accurately.
#
#
# **3. `days_since_last_review`**
# - **Construction:** Number of days elapsed between `last_review` and the snapshot
#   date (2025-12-01).
# - **Justification:** Recently reviewed listings signal active demand. Listings
#   with no recent reviews may be underpriced or less popular, which affects price.
#
#
# **4. `is_commercial_host`**
# - **Construction:** Binary flag — 1 if `host_listings_count > 1`, else 0.
# - **Justification:** Commercial hosts managing multiple listings tend to price
#   more strategically and maintain higher quality standards, which may correlate
#   with higher prices.
#
#
# **5. `beds_per_person`**
# - **Construction:** `beds / accommodates`. Zero denominator is replaced with NaN
#   and imputed in the missing value step.
# - **Justification:** A higher bed-to-guest ratio indicates greater comfort.
#   Listings with more beds per person can justify higher prices.
#
#
# **6. `bath_to_bedroom_ratio`**
# - **Construction:** `bathrooms / bedrooms`. Zero denominator is replaced with NaN
#   and imputed in the missing value step.
# - **Justification:** More bathrooms relative to bedrooms is a proxy for luxury.
#   Higher ratios are associated with premium listings.
#
#
# **7. `accommodates_per_bedroom`**
# - **Construction:** `accommodates / bedrooms`. Zero denominator is replaced with
#   NaN and imputed in the missing value step.
# - **Justification:** Measures space density — lower values indicate more spacious
#   listings, which typically command higher prices per guest.
#
#
# **8. `availability_rate`**
# - **Construction:** `availability_365 / 365`, giving a proportion in [0, 1].
# - **Justification:** Low availability may indicate high demand, which supports
#   higher pricing. Highly available listings may be less sought-after and priced
#   lower to attract bookings.
#
#
# **9. `dist_to_cbd`**
# - **Construction:** Haversine great-circle distance (km) from the listing's
#   coordinates to Brisbane CBD (−27.4698°, 153.0251°).
# - **Justification:** Proximity to the CBD is a key price driver in urban markets.
#   Listings closer to the city centre typically command a premium due to
#   convenience and accessibility.
#
#
# **10. `geo_cluster`**
# - **Construction:** K-Means clustering (k = 5) applied to StandardScaler-
#   normalised latitude and longitude. The scaler and cluster centroids were fit on
#   the training set only; the test set was transformed using the same parameters.
# - **Justification:** Captures spatial price patterns beyond a single distance
#   metric. Neighbourhoods within the same zone share similar price levels,
#   providing richer location signal than `dist_to_cbd` alone.
#
#
# ##### Dropped Source Columns
#
# After feature engineering, the following source columns were dropped as their
# information has been fully captured by the new features:
#
# | Dropped Column | Replaced By |
# |---|---|
# | `availability_365` | `availability_rate` (normalised version) |
# | `latitude`, `longitude` | `dist_to_cbd` + `geo_cluster` |
# | `host_since` | `host_experience_days` |
# | `last_review`, `first_review` | `days_since_last_review` |

# %% [markdown]
# ### **Room for Improvement 1:**

# %%
# --- Ammenities handle
AMENITY_MAP = {
    'has_wifi'             : r'wi-?fi',
    'has_heating'          : r'heating',
    'has_essentials'       : r'essentials',
    'has_kitchen'          : r'kitchen',
    'has_smoke_alarm'      : r'smoke alarm',
    'has_air_conditioning' : r'air conditioning',
    'has_hangers'          : r'hangers',
    'has_workspace'        : r'workspace',
    'has_coffee_maker'     : r'coffee maker',
    'has_hot_water_kettle' : r'hot water kettle',
    'has_hair_dryer'       : r'hair dryer',
    'has_iron'             : r'\biron\b',                 
    'has_tv'               : r'\btv\b|hdtv|television',   
    'has_hot_water'        : r'hot water(?! kettle)',     
    'has_washer'           : r'\bwasher\b',               
    'has_dryer'            : r'(?<!hair )dryer',         
    'has_first_aid_kit'    : r'first aid kit',
    'has_fire_extinguisher': r'fire extinguisher',
    'has_refrigerator'     : r'refrigerator',
    'has_pool'             : r'\bpool\b',                 
    'has_gym'              : r'gym|fitness|exercise equipment',  
    'has_pets_allowed'     : r'pets allowed',
    'has_free_parking'     : r'free[^"]*parking',        
    'has_paid_parking'     : r'paid[^"]*parking',      
    'has_self_checkin'     : r'self check-?in',
}
# Selecting top n amentities based on train frequency
TOP_N = len(AMENITY_MAP)

# Binary setting for train and test based on Amentity_MAP
for df in [train_data, test_data]:
    amenities_str = df['amenities'].fillna('[]').str.lower()
    for col, pattern in AMENITY_MAP.items():
        df[col] = amenities_str.str.contains(pattern, regex=True).astype(int)

# ── Name keyword features ────────────────────────────────────────────────
NAME_KEYWORDS = {
    'name_luxury'   : r'luxury|luxurious',
    'name_pool'     : r'\bpool\b',
    'name_view'     : r'\bview\b|views',
    'name_studio'   : r'\bstudio\b',
    'name_cbd'      : r'\bcbd\b|city centre|city center',
    'name_beach'    : r'\bbeach\b|beachside|beachfront',
    'name_ocean'    : r'\bocean\b',
    'name_penthouse': r'\bpenthouse\b',
    'name_modern'   : r'\bmodern\b|contemporary',
}
for df in [train_data, test_data]:
    name_str = df['name'].fillna('').str.lower()
    for col, pattern in NAME_KEYWORDS.items():
        df[col] = name_str.str.contains(pattern, regex=True).astype(int)

NAME_FEATURES = list(NAME_KEYWORDS.keys())
print(f"Name keyword features: {NAME_FEATURES}")

# Calculate frequency of amenities map on train
all_cols = list(AMENITY_MAP.keys())
freq = train_data[all_cols].mean().sort_values(ascending=False)
print("Frequency amenity (train):")
print(freq.round(3).to_string())
 
kept = freq[freq >= 0.0].index[:TOP_N].tolist()
dropped = [c for c in all_cols if c not in kept]
print(f"\keep {len(kept)} cols | Drop: {dropped if dropped else 'None'}")

# add amenity features to list of selected feature
for df in [train_data, test_data]:
    df.drop(columns=[c for c in dropped if c in df.columns], inplace=True)
 
AMENITY_FEATURES = kept
# Out:
# <>:66: SyntaxWarning: invalid escape sequence '\k'
# <>:66: SyntaxWarning: invalid escape sequence '\k'
# /var/folders/fs/vpv7t9012wxdx__nwt82lmpm0000gn/T/ipykernel_84117/1785338442.py:66: SyntaxWarning: invalid escape sequence '\k'
#   print(f"\keep {len(kept)} cols | Drop: {dropped if dropped else 'None'}")
# Name keyword features: ['name_luxury', 'name_pool', 'name_view', 'name_studio', 'name_cbd', 'name_beach', 'name_ocean', 'name_penthouse', 'name_modern']
# Frequency amenity (train):
# has_wifi                 0.960
# has_smoke_alarm          0.955
# has_kitchen              0.953
# has_washer               0.925
# has_tv                   0.902
# has_hot_water            0.804
# has_hangers              0.792
# has_refrigerator         0.787
# has_air_conditioning     0.782
# has_hair_dryer           0.776
# has_iron                 0.773
# has_free_parking         0.740
# has_hot_water_kettle     0.721
# has_essentials           0.674
# has_self_checkin         0.652
# ...

# %% [markdown]
# ### Amenity & Listing Name Features
#
# In addition to `amenities_count`, individual binary features were extracted from
# the `amenities` JSON string and the listing `name` field to capture the presence
# of specific attributes that may influence price.
#
# ---
#
# **Amenity Binary Features (`has_*`)**
# - Given some research, one particular column of interest was ‘amenities’, a text variable with over 2000 unique values. To handle this, we performed examination, cleaning, aggregation and split the column into individual binary variables. Each binary variable represented whether a particular amenity was included in the listing, with 1 indicating its presence and 0 indicating otherwise.
# - The identification of the top 25 amenities was carried out by leveraging insights from various research studies that focused on investigating their impact, including a list given below:
# WiFi, heating, essentials, kitchen, smoke alarm, air conditioning, hangers, workspace, coffee maker, hot water kettle, hair dryer, iron, TV, hot water, washer, dryer, first aid kit, fire extinguisher, refrigerator, pool, gym, pets allowed, free parking, paid parking, self check-in
#
# - The way to reduce the this dimention is select top amentities that our group think that they are most effectively influencing on airbnb pricing, combining with external research about the preffered amentities list and top frequency on trainning data
#
# - **Construction:** For each amenity in `AMENITY_MAP`, a binary flag (1/0) is
#   created by applying a regular expression pattern to the lowercased `amenities`
#   string. Special patterns are used to avoid false matches. For example,
#   `\biron\b` matches "iron" but not "hair iron", and `(?<!hair )dryer` matches
#   "dryer" but not "hair dryer".
# - **Features extracted (25 total):** `has_wifi`, `has_heating`, `has_essentials`,
#   `has_kitchen`, `has_smoke_alarm`, `has_air_conditioning`, `has_hangers`,
#   `has_workspace`, `has_coffee_maker`, `has_hot_water_kettle`, `has_hair_dryer`,
#   `has_iron`, `has_tv`, `has_hot_water`, `has_washer`, `has_dryer`,
#   `has_first_aid_kit`, `has_fire_extinguisher`, `has_refrigerator`, `has_pool`,
#   `has_gym`, `has_pets_allowed`, `has_free_parking`, `has_paid_parking`,
#   `has_self_checkin`.
# - **Justification:** Individual amenities signal different tiers of comfort and
#   convenience. Premium amenities such as a pool, gym, or air conditioning are
#   associated with higher-priced listings, while basic amenities (wifi, kitchen)
#   are nearly universal and act as quality-floor signals.
#
# ---
#
# **Listing Name Keyword Features (`name_*`)**
#
# - **Construction:** For each keyword in `NAME_KEYWORDS`, a binary flag (1/0) is
#   created by applying a regular expression to the lowercased `name` field.
# - **Features extracted (9 total):** `name_luxury`, `name_pool`, `name_view`,
#   `name_studio`, `name_cbd`, `name_beach`, `name_ocean`, `name_penthouse`,
#   `name_modern`.
# - **Justification:** Hosts deliberately use premium keywords in listing titles to
#   signal quality and attract higher-paying guests. Listings mentioning "luxury",
#   "penthouse", or "ocean" are likely priced higher than comparable listings
#   without such descriptors, making these keywords useful price signals.
#
# ---
#
# **Frequency Filtering**
#
# Amenity frequency was calculated on the training set only to avoid data leakage.
# All 25 amenities in `AMENITY_MAP` were retained as their frequency threshold was
# set to ≥ 0 — meaning no amenity was dropped at this stage. This ensures the full
# set of hand-curated amenity signals is preserved for model training.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 3. Missing Values (2 marks)
#
# Impute missing values for all selected features.
# - Identify variables with missing values
# - Apply appropriate imputation methods (e.g. mean, median, mode, or other suitable approaches)
# - Ensure that the same imputation strategy is applied consistently to both datasets
# - Briefly explain and justify the method used for different types of variable

# %%
# Assemble train_data_selection / test_data_selection
REVIEW_SCORE_FEATURES = [
    'review_scores_rating', 'review_scores_cleanliness',
    'review_scores_location', 'review_scores_accuracy',
    'review_scores_communication', 'review_scores_checkin',
    'review_scores_value'
]

BASE_NUM_FEATURES = [
    'host_response_rate', 'host_acceptance_rate',
    'host_listings_count',
    'estimated_occupancy_l365d',
    'accommodates', 'bathrooms', 'bedrooms', 'beds',
    'minimum_nights', 'maximum_nights',
    'availability_30',
    'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
    'reviews_per_month',
    *REVIEW_SCORE_FEATURES,
]

ENG_NUM_FEATURES = [
    'amenities_count', 'host_experience_days', 'days_since_last_review',
    'is_commercial_host', 'beds_per_person', 'bath_to_bedroom_ratio',
    'accommodates_per_bedroom', 'availability_rate', 'dist_to_cbd',
]

CAT_FEATURES  = ['room_type', 'property_type', 'neighbourhood_cleansed',
                 'host_response_time', 'geo_cluster']

BOOL_FEATURES = ['host_is_superhost', 'instant_bookable', 'host_identity_verified']

ALL_FEATURES = (BASE_NUM_FEATURES + ENG_NUM_FEATURES + CAT_FEATURES
                + BOOL_FEATURES + AMENITY_FEATURES + NAME_FEATURES)

train_cols = [c for c in ALL_FEATURES if c in train_data.columns]
test_cols  = [c for c in ALL_FEATURES if c in test_data.columns]

train_data_selection = train_data[train_cols + ['price']].copy()
test_data_selection  = test_data[test_cols].copy()

print(f"train_data_selection: {train_data_selection.shape}")
print(f"test_data_selection : {test_data_selection.shape}")
# Out:
# train_data_selection: (3735, 74)
# test_data_selection : (1601, 73)

# %%
train_data_selection.columns
# Out:
# Index(['host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'estimated_occupancy_l365d', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'minimum_nights', 'maximum_nights', 'availability_30',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'reviews_per_month', 'review_scores_rating',
#        'review_scores_cleanliness', 'review_scores_location',
#        'review_scores_accuracy', 'review_scores_communication',
#        'review_scores_checkin', 'review_scores_value', 'amenities_count',
#        'host_experience_days', 'days_since_last_review', 'is_commercial_host',
#        'beds_per_person', 'bath_to_bedroom_ratio', 'accommodates_per_bedroom',
#        'availability_rate', 'dist_to_cbd', 'room_type', 'property_type',
#        'neighbourhood_cleansed', 'host_response_time', 'geo_cluster',
#        'host_is_superhost', 'instant_bookable', 'host_identity_verified',
# ...

# %% [markdown]
# **Check variables with missing value:**

# %% [markdown]
# **Check distribution of missing value of numeric features**

# %%
import math

median_plot_cols = [
    'bathrooms', 'beds', 'bedrooms', 'host_listings_count',
    'host_response_rate', 'host_acceptance_rate', 'host_experience_days',
    'beds_per_person', 'bath_to_bedroom_ratio', 'accommodates_per_bedroom',
    'review_scores_rating', 'review_scores_cleanliness', 'review_scores_location',
    'review_scores_accuracy', 'review_scores_communication',
    'review_scores_checkin', 'review_scores_value',
]

ncols = 6
nrows = math.ceil(len(median_plot_cols) / ncols)

fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 3.5, nrows * 3))
axes = axes.flatten()

for ax, col in zip(axes, median_plot_cols):
    data = train_data_selection[col].dropna()
    ax.hist(data, bins=40, color='steelblue', edgecolor='none')
    ax.set_title(f'{col}\nskew={data.skew():.2f}', fontsize=8)
    ax.set_xlabel('')
    ax.set_ylabel('Count', fontsize=7)
    ax.tick_params(labelsize=7)
for ax in axes[len(median_plot_cols):]:
    ax.set_visible(False)

plt.suptitle('Distribution of Median-Imputed Features (Before Imputation)', fontsize=12, y=1.01)
plt.tight_layout()
plt.show()

# %%
# Compute imputation values from TRAIN only (avoid data leakage)
REVIEW_SCORE_FEATURES = [
    'review_scores_rating', 'review_scores_cleanliness',
    'review_scores_location', 'review_scores_accuracy',
    'review_scores_communication', 'review_scores_checkin',
    'review_scores_value'
]

median_num_cols = [
    'bathrooms', 'beds', 'bedrooms', 'host_listings_count',
    'host_response_rate', 'host_acceptance_rate',
    'host_experience_days', 'beds_per_person', 'bath_to_bedroom_ratio',
    'accommodates_per_bedroom',
    *REVIEW_SCORE_FEATURES,
]
medians = train_data_selection[median_num_cols].median()
max_day_no_review = train_data_selection['days_since_last_review'].max()

for df in [train_data_selection, test_data_selection]:
    df['days_since_last_review'] = df['days_since_last_review'].fillna(max_day_no_review)
    df['reviews_per_month']      = df['reviews_per_month'].fillna(0)
    for col in median_num_cols:
        df[col] = df[col].fillna(medians[col])
    df['host_response_time']     = df['host_response_time'].fillna('unknown')
    df['host_is_superhost']      = df['host_is_superhost'].fillna('f')
    df['host_identity_verified'] = df['host_identity_verified'].fillna('f')

nan_check = train_data_selection[median_num_cols].isna().sum().sum()
print(f"NaN remaining after imputation: {nan_check}")
# Out:
# NaN remaining after imputation: 0

# %% [markdown]
# After handling the missing value, I used the `report_missing()` function to check whether there are any null values left. The output show that the dataset has no more missing values

# %% [markdown]
# ### Missing Value Imputation
#
# Missing values were handled differently depending on the nature of each feature.
# All imputation parameters were computed on the training set only and then applied
# to the test set to avoid data leakage.
#
#
# **1. Median Imputation — Continuous Numerical Features**
#
# Features: `bathrooms`, `beds`, `bedrooms`, `host_listings_count`,
# `host_response_rate`, `host_acceptance_rate`, `host_experience_days`,
# `beds_per_person`, `bath_to_bedroom_ratio`, `accommodates_per_bedroom`,
# and all `review_scores_*` features.
#
# The median of each feature was computed from the training set and used to fill
# missing values in both train and test. Median was chosen over mean because
# several of these features are right-skewed with outliers — the median is more
# robust and better represents the typical listing.
#
# **2. Zero Imputation —** `reviews_per_month`
#
# Missing values in `reviews_per_month` indicate listings that have never been
# reviewed. Filling with 0 is semantically correct — these listings have zero
# reviews per month rather than an unknown value.
#
#
# **3. Maximum Value Imputation —** `days_since_last_review`
#
# Listings with no review have a missing `last_review` date, meaning
# `days_since_last_review` cannot be computed. These are imputed with the maximum
# observed value in the training set, representing the longest time since any
# listing was last reviewed. This correctly signals that these listings are the
# least recently reviewed — more extreme than any observed value would be
# inappropriate as it could extrapolate beyond the data.
#
#
# **4. Constant Imputation — Categorical & Binary Features**
#
# - `host_response_time` → filled with `'unknown'`: missing response time suggests
#   the host has not set a response policy, which is meaningfully different from
#   any of the four response time categories.
# - `host_is_superhost` → filled with `'f'` (False): a missing superhost status is
#   most likely a non-superhost host, as the badge is explicitly awarded and
#   displayed.
# - `host_identity_verified` → filled with `'f'` (False): same reasoning — verified
#   status is explicitly granted and displayed; missing implies not verified.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 4. Encoding Categorical Variables (2 marks)
#
# Encode all categorical variables appropriately.
# - Identify all categorical features in the dataset
# - For features with more than 5 unique values, retain the 5 most frequent categories and group the remaining values into an "other" category
# - Apply an appropriate encoding method, i.e. ordinal vs. nominal
# - Ensure that encoding is applied consistently to both the training and test datasets
# - Briefly explain your encoding choices

# %% [markdown]
# ##### Comments:
# All the categorical features that has been selected are: `room_type`, `property_type`, `neighbourhood_cleansed`, `host_response_time`, `geo_cluster`

# %%
train_data_selection[CAT_FEATURES]
# Out:
#             room_type             property_type  neighbourhood_cleansed  \
# 0     Entire home/apt        Entire rental unit  Rocklea - Acacia Ridge
# 1     Entire home/apt        Entire guest suite                  Wynnum
# 2     Entire home/apt        Entire rental unit        Fortitude Valley
# 3     Entire home/apt        Entire rental unit  Newstead - Bowen Hills
# 4     Entire home/apt        Entire rental unit        Fortitude Valley
# ...               ...                       ...                     ...
# 3730     Private room      Private room in home            Holland Park
# 3731     Private room  Private room in bungalow               Robertson
# 3732  Entire home/apt        Entire rental unit          South Brisbane
# 3733  Entire home/apt        Entire rental unit  Kelvin Grove - Herston
# 3734     Private room     Private room in condo           Brisbane City
#
#       host_response_time geo_cluster
# 0         within an hour      zone_1
# ...

# %% [markdown]
# **a. High-Cardinality Nominal Features — Collapsing + One-Hot Encoding**
#
# - Features: `room_type`, `property_type`, `neighbourhood_cleansed`, `geo_cluster`
#
# - For features with more than 5 unique values, the 5 most frequent categories
# were retained and all remaining values were grouped into an `"other"` category.
# The top-5 lists were derived from the training set only to avoid data leakage,
# then applied to the test set using the same mapping.
#     - `property_type`: Some cleaning and modification in property type is required as there was a large number of categories with only a few listings. We kept top 5 frequency of property type in training set and assign the rest as 'other'. We have the most frequenct of entire rental unit of 0.48% of total property types.
#     - `neighbourhood_cleansed`: Use the same method that is applied for `property_type`, even though the huge amount of unique value observed in this categories, but we first encode as simple as possible. Then we consider another encode for any improvements later in task 3
#     - `room_type` and `geo_cluster` has less than 5 distinct values so the we just applied the normal one-hot encoding.
#
# - **One-hot encoding** was then applied via `pd.get_dummies`. The test set was
# realigned to match the training set's dummy columns using `reindex`, filling
# any unseen categories with 0. This ensures the feature matrix passed to the
# model has identical columns across train and test.
#
# - One-hot encoding was chosen because these features have no natural ordering —
# for example, there is no inherent ranking between `room_type` categories such
# as "Entire home/apt" and "Private room". Assigning arbitrary integer labels
# would incorrectly imply an order that does not exist.
#     - 1: indicates that the listing belongs to that room type/property type/neighbourhood/geo cluster,
#     - 0: indicates that it does not.

# %%
# ── Step 1: Collapse high-cardinality nominal features 
# For features with >5 unique values, keep top 5 by frequency; rest → 'other'
CAT_NOMINAL  = ['room_type', 'property_type', 'neighbourhood_cleansed', 'geo_cluster']

TOP_N = 5
for col in CAT_NOMINAL:
    # Derive top categories from TRAIN only (avoid data leakage)
    top_cats = train_data_selection[col].value_counts().nlargest(TOP_N).index
    for df in [train_data_selection, test_data_selection]:
        df[col] = df[col].where(df[col].isin(top_cats), other='other')

print("Unique categories after collapsing (train):")
for col in CAT_NOMINAL:
    counts = train_data_selection[col].value_counts()
    print(f"\n  {col}:")
    print(counts.to_string())
# Out:
# Unique categories after collapsing (train):
#
#   room_type:
# room_type
# Entire home/apt    2854
# Private room        875
# Shared room           4
# Hotel room            2
#
#   property_type:
# property_type
# Entire rental unit             1804
# Entire home                     596
# Private room in home            513
# other                           504
# Private room in rental unit     196
# Entire guest suite              122
#
#   neighbourhood_cleansed:
# neighbourhood_cleansed
# other                     2298
# Brisbane City              567
# South Brisbane             314
# Fortitude Valley           277
# Newstead - Bowen Hills     149
# Spring Hill                130
#
#   geo_cluster:
# geo_cluster
# zone_4    2798
# zone_1     528
# zone_0     232
# zone_2     151
# zone_3      26

# %%
# # Step 2: One-hot encoding for nominal features
# Fit on TRAIN categories only; reindex TEST to match (fills unseen cols with 0)
cat_nominal = ['room_type', 'property_type', 'neighbourhood_cleansed', 'geo_cluster']

cat_dummies_train = pd.get_dummies(train_data_selection[cat_nominal],dtype= int)
cat_dummies_test  = pd.get_dummies(test_data_selection[cat_nominal],  dtype= int)
# Align test columns to match train (handles unseen data == 0)
cat_dummies_test  = cat_dummies_test.reindex(columns=cat_dummies_train.columns, fill_value=0)

# %%
# Categorical variables to check after encoding
cat_check = {
    'room_type'               : 'room_type',
    'property_type'           : 'property_type',
    'neighbourhood_cleansed'  : 'neighbourhood_cleansed',
    'geo_cluster'             : 'geo_cluster',
    'host_response_time'      : 'host_response_time',  
    'host_is_superhost'       : 'host_is_superhost',
    'instant_bookable'        : 'instant_bookable',
    'host_identity_verified'  : 'host_identity_verified',
}

fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

for ax, (title, col) in zip(axes, cat_check.items()):
    order = (train_data_selection[col]
             .value_counts()
             .sort_values(ascending=False)
             .index)
    sns.countplot(data=train_data_selection, x=col,
                  order=order, palette='Set2', ax=ax)
    ax.set_title(f'Count by {title}', fontsize=10)
    ax.set_xlabel('')
    ax.set_ylabel('Count', fontsize=8)
    ax.tick_params(axis='x', rotation=20, labelsize=8)

plt.suptitle('Category Distribution of Encoded Categorical Features', fontsize=13, y=1.01)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/fs/vpv7t9012wxdx__nwt82lmpm0000gn/T/ipykernel_84117/1585886993.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train_data_selection, x=col,
# /var/folders/fs/vpv7t9012wxdx__nwt82lmpm0000gn/T/ipykernel_84117/1585886993.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train_data_selection, x=col,
# /var/folders/fs/vpv7t9012wxdx__nwt82lmpm0000gn/T/ipykernel_84117/1585886993.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train_data_selection, x=col,
# ...

# %% [markdown]
# The median price is distinguished pretty well after encoding for n>5 unique value

# %% [markdown]
# **b. Ordinal Feature — Ordinal Encoding**
#
# Feature: `host_response_time`
#
# This feature has a clear natural ordering from fastest to slowest response.
# It was encoded as integers 0–4 preserving this ranking:
#
# | Category | Encoded Value |
# |---|---|
# | within an hour | 0 |
# | within a few hours | 1 |
# | within a day | 2 |
# | a few days or more | 3 |
# | unknown | 4 |
#
# Note that `unknown` (imputed from missing values in the previous step) was
# assigned the highest value, representing the worst-case response behaviour —
# a host with no recorded response time is treated as the least responsive.

# %%
# Step 3: Ordinal encoding for host_response_time 
# Clear speed order: faster response → lower integer value; 'unknown' → highest reponse time 
response_order = {
    'within an hour'    : 0,
    'within a few hours': 1,
    'within a day'      : 2,
    'a few days or more': 3,
    'unknown'           : 4,
}
for df in [train_data_selection, test_data_selection]:
    df['host_response_time'] = df['host_response_time'].map(response_order)

# %% [markdown]
# **c. Binary Features — Boolean Mapping (t/f → 1/0)**
#
# Features: `host_is_superhost`, `instant_bookable`, `host_identity_verified`
#
# These features take only two values (`t`/`f`). They were mapped directly to
# 1 and 0. This is equivalent to one-hot encoding with a single column and
# avoids creating a redundant second dummy column.

# %%
# # Step 4: Convert boolean 't'/'f' → 1/0
bool_cols = ['host_is_superhost', 'instant_bookable', 'host_identity_verified']
for df in [train_data_selection, test_data_selection]:
    for col in bool_cols:
        df[col] = df[col].map({'t': 1, 'f': 0})

# %% [markdown]
# ### Summary:
#
# | Feature | Type | Categories after collapsing | Method | Reason |
# |---|---|---|---|---|
# | `room_type` | Nominal | 4 (all retained, ≤ 5) | One-hot | No natural order; all 4 categories kept as-is |
# | `property_type` | Nominal | 6 (top 5 + *other*) | One-hot | No natural order; low-frequency types collapsed into *other* to reduce noise |
# | `neighbourhood_cleansed` | Nominal | 6 (top 5 + *other*) | One-hot | Same rationale as `property_type` |
# | `host_response_time` | Ordinal | 5 | Label (0–4) | Clear speed ordering: *within an hour* (0) → *within a few hours* (1) → *within a day* (2) → *a few days or more* (3) → *unknown* (4) |
# | `host_is_superhost` | Boolean | 2 | Binary (0/1) | Already binary; integer mapping is sufficient |
# | `instant_bookable` | Boolean | 2 | Binary (0/1) | Same as above |
# | `host_identity_verified` | Boolean | 2 | Binary (0/1) | Same as above |

# %% [markdown]
# #### **Room for Improvement 2**:

# %%
# # Define final numeric feature list (used in Section 5)
exclude = cat_nominal + ['price']     
all_features = [c for c in train_data_selection.columns if c not in exclude]
all_features
# Out:
# ['host_response_rate',
#  'host_acceptance_rate',
#  'host_listings_count',
#  'estimated_occupancy_l365d',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'minimum_nights',
#  'maximum_nights',
#  'availability_30',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'reviews_per_month',
#  'review_scores_rating',
#  'review_scores_cleanliness',
#  'review_scores_location',
#  'review_scores_accuracy',
#  'review_scores_communication',
#  'review_scores_checkin',
#  'review_scores_value',
#  'amenities_count',
#  'host_experience_days',
#  'days_since_last_review',
#  'is_commercial_host',
#  'beds_per_person',
#  'bath_to_bedroom_ratio',
#  'accommodates_per_bedroom',
#  'availability_rate',
#  'dist_to_cbd',
#  'host_response_time',
#  'host_is_superhost',
#  'instant_bookable',
#  'host_identity_verified',
#  'has_wifi',
#  'has_smoke_alarm',
#  'has_kitchen',
#  'has_washer',
#  'has_tv',
#  'has_hot_water',
#  'has_hangers',
# ...

# %%
from sklearn.model_selection import KFold

# 5-fold target encoding for neighbourhood_cleansed
# Fit on train folds only (no leakage); test uses full-train mean per suburb
y_te        = np.log1p(train_data_selection['price'])
nc_train    = train_data['neighbourhood_cleansed']   # full 132 suburbs (pre-collapse)
nc_test     = test_data['neighbourhood_cleansed']
global_mean = y_te.mean()

kf = KFold(5, shuffle=True, random_state=42)
nc_te_train = np.zeros(len(train_data_selection))
for tr_idx, val_idx in kf.split(train_data_selection):
    fold_mean = y_te.iloc[tr_idx].groupby(nc_train.iloc[tr_idx]).mean()
    nc_te_train[val_idx] = nc_train.iloc[val_idx].map(fold_mean).fillna(global_mean).values

full_mean = y_te.groupby(nc_train).mean()
nc_te_test = nc_test.map(full_mean).fillna(global_mean).values

train_data_selection['neighbourhood_te'] = nc_te_train
test_data_selection['neighbourhood_te']  = nc_te_test

# Append to all_features so X_train/X_test include it
all_features.append('neighbourhood_te')

corr = np.corrcoef(nc_te_train, y_te)[0,1]
print(f"neighbourhood_te added — corr with log_price: {corr:.3f}  (top-5 OHE was ~0.215)")
# Out:
# neighbourhood_te added — corr with log_price: 0.369  (top-5 OHE was ~0.215)

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 5. Additional Data Preparation (2 marks)
#
# Perform any additional data preparation steps required before building predictive models.
# - Consider steps such as scaling, transformations, or handling outliers
# - Ensure that any transformations are applied consistently to both the training and test datasets
# - Clearly describe each step you perform
# - Briefly justify why these steps are necessary

# %% [markdown]
# ### Check for skewness (count numeric variable and price)

# %%
ENG_NUM_FEATURES = [
    'amenities_count', 'host_experience_days', 'days_since_last_review',
    'is_commercial_host', 'beds_per_person', 'bath_to_bedroom_ratio',
    'accommodates_per_bedroom', 'availability_rate', 'dist_to_cbd'
]
fig, axes = plt.subplots(3, 3, figsize=(15,9))
for ax, col in zip(axes.flatten(), ENG_NUM_FEATURES):
    ax.hist(train_data_selection[col].dropna(), bins=40,
            color='steelblue', edgecolor='none')
    ax.set_title(f'{col}\nskew={train_data_selection[col].skew():.1f}', fontsize=8)
    ax.set_ylabel('Count')
plt.suptitle('Count / Duration Variables — before log transform', fontsize=11)
plt.tight_layout()
plt.show()

# %%
skew_before = train_data_selection[BASE_NUM_FEATURES].skew().round(2)
skew_before
# Out:
# host_response_rate             -5.43
# host_acceptance_rate           -2.65
# host_listings_count             3.52
# estimated_occupancy_l365d       0.70
# accommodates                    1.60
# bathrooms                       2.55
# bedrooms                        1.59
# beds                            2.93
# minimum_nights                 18.42
# maximum_nights                  1.01
# availability_30                 0.35
# number_of_reviews               4.01
# number_of_reviews_ltm           2.27
# number_of_reviews_l30d          2.07
# reviews_per_month               1.71
# review_scores_rating           -5.17
# review_scores_cleanliness      -4.52
# review_scores_location         -6.39
# review_scores_accuracy         -6.07
# review_scores_communication    -6.78
# review_scores_checkin          -5.40
# review_scores_value            -4.94
# dtype: float64

# %% [markdown]
# **Skewness and Scaling Decision:**
#
# The skewness check reveals that several features exhibit moderate to severe right-skew,
# particularly count and duration variables such as `minimum_nights`, `host_listings_count`,
# and `days_since_last_review`. However, all three models selected - Decision Tree, Random Forest, and Gradient Boosting - are tree-based and operate via threshold splits rather than distance or gradient calculations.
# They are inherently insensitive to feature scale and skewed distributions. Feature scaling
# was therefore not applied, avoiding unnecessary transformation and reducing pipeline complexity.

# %% [markdown]
# ### Log-transform the Target Variable and Assemble X and y for Models training

# %%
# Log-transform the target variable (price)
print(f"Price skewness — original : {train_data_selection['price'].skew():.2f}")
y_train = np.log1p(train_data_selection['price'])
print(f"Price skewness — log1p    : {y_train.skew():.2f}")

# Assemble feature matrices
X_train = pd.concat([
    train_data_selection[all_features].reset_index(drop=True),
    cat_dummies_train.reset_index(drop=True),
], axis=1)

X_test = pd.concat([
    test_data_selection.reindex(columns=all_features, fill_value=0).reset_index(drop=True),
    cat_dummies_test.reset_index(drop=True),
], axis=1)

# Safety net: replace any residual inf with NaN, then fill with column median
for df in [X_train, X_test]:
    df.replace([np.inf, -np.inf], np.nan, inplace=True)

col_medians = X_train.median()
X_train.fillna(col_medians, inplace=True)
X_test.fillna(col_medians, inplace=True)

assert list(X_train.columns) == list(X_test.columns), "Column mismatch"
inf_remaining = np.isinf(X_train.values).sum()
nan_remaining = X_train.isna().sum().sum()
print(f"X_train: {X_train.shape},  X_test: {X_test.shape}")
print(f"inf in X_train: {inf_remaining}  |  NaN in X_train: {nan_remaining}")
# Out:
# Price skewness — original : 7.48
# Price skewness — log1p    : 0.25
# X_train: (3735, 91),  X_test: (1601, 91)
# inf in X_train: 0  |  NaN in X_train: 0

# %% [markdown]
# **Check distribution of `price` after transformation:**

# %%
# Create the histogram
plt.hist(y_train, bins=30, color='skyblue', edgecolor='black')

# Add titles and labels
plt.title('Price distribution')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# **Log-transformation of the target variable (`price`):**
#
# After applying `log1p`, the transformed price distribution is approximately symmetric
# with a skewness of 0.251 — a substantial improvement from the original raw skewness of ~7–8.
#
# The **mean** (5.246) and **median** (5.268) are nearly identical, differing by only 0.022, confirming
# that the log transformation has effectively compressed the central distribution.
#
# The **standard deviation** of 0.603
# in log space indicates moderate spread around the centre.
#
# However, the histogram reveals that a small number of **outliers** remain — a right tail
# extending beyond 7 and a few low-value observations near 3–4 represent unusually cheap listings. These
# extreme values are not removed, as they reflect genuine market observations rather than
# data errors. Tree-based models such as Random Forest and Gradient Boosting are robust
# to such outliers since they partition the feature space by threshold splits rather than
# being influenced by the magnitude of individual values.
#
# Predictions are back-transformed using `np.expm1()` before submission.

# %% [markdown]
# ---
# ---
# ## Task 3: Model Fitting, Tuning, and Prediction
#
# **Total Marks: 10**
#
# - Use the dataset obtained from **Task 2** for this task.
# - Do not create any new features. You must rely only on the variables constructed in Task 2.
# - Ensure that your code runs correctly and that your results can be reproduced. Your submitted forecasts must be generated directly from your code.

# %% [markdown]
# Student in charge of this task: `Quynh Huong Nguyen`
# Student ID: `48734055`

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 1. Initial Model Set (2 marks)
#
# Define an initial set of three different machine learning models to apply in this task.
# - Briefly explain how each model works at a high level
# - Highlight key differences between the models
# - Discuss the advantages and disadvantages of each model in the context of this problem
# <hr style="width:25%;margin-left:0;">

# %%
# Recall X train and X_test
X_train
X_test

# Recall y_train only `log_Price`
y_train
# Out:
# 0       4.584967
# 1       5.327876
# 2       5.231109
# 3       5.062595
# 4       5.707110
#           ...
# 3730    4.709530
# 3731    4.158883
# 3732    5.446737
# 3733    5.303305
# 3734    4.564348
# Name: price, Length: 3735, dtype: float64

# %% [markdown]
# **a. Model Explaination**
#
# We trained and compared three models as our initial set: OLS (standard linear regression), Lasso (regularised linear regression), and Random Forest. The improvement is making a room for more powerful ensemble models such as XGBoost and CatBoost.
#
# - `The OLS` fits a straight line through the data by finding the combination of feature weights that minimises prediction error. It is simple, fast, and easy to interpret. We used it as a baseline to understand how much of the price variation can be explained by a purely linear relationship. Its main weakness here is that price depends on combinations of features (e.g. location × room type) that a straight line cannot capture.. However, the OLS cannot be used to model data with non linear relationship (_Hastie et al., 2017_)
#
#     $$
#     \hat{y} = w_1 x_1 + w_2 x_2 + \dots + w_p x_p + b = \mathbf{w}^\top \mathbf{x} + b
#     $$
#
# - Lasso works the same way as OLS but adds a penalty for large coefficients. In `Lasso`, we were tunning parameter alpha is first set by CV, and then L1 regularization is performed. The lasso model is a extending method based on Linear regression by adding a penalty part, aiming to prevent model from overfitting that OLS usually did. Their formular of prediction is still the same as above, but following by an optimized equation. The strength of this penalty is controlled by a value called alpha, which we tuned using cross-validation. Lasso improves on OLS when some features are redundant, but still cannot capture non-linear patterns.
#     $$
#     \min_{\mathbf{w}} \; \sum_{i=1}^{n} \left( y_i - \hat{y}_i \right)^2 + \alpha \sum_{j=1}^{p} |w_j|
#     $$
#
# - The tree-based model `RandomForest`takes a completely different approach — it builds many decision trees, each trained on a random subset of the data and features, then averages their predictions. Unlike the two linear models, it can naturally pick up non-linear relationships (e.g. the sharp price jump for waterfront properties) without requiring log-transforms on every feature. The trade-off is that it is harder to interpret and more prone to overfitting on training data (as we will observe below).

# %% [markdown]
# **Key difference**
# | | OLS | Lasso | Random Forest |
# |---|---|---|---|
# | **Relationship type** | Linear only | Linear only | Linear & non-linear |
# | **Feature selection** | No | Yes (shrinks to zero) | No (but uses feature importance) |
# | **Overfitting risk** | Low | Low | Higher on training data |
# | **Interpretability** | High | High | Lower |

# %% [markdown]
# **b. COMPARE BASE MODEL: _Linear regression with OLS vs Lasso vs Random Forest_**

# %% [markdown]
# **Model performance and 5-fold cross validation given default hyperparameter**

# %%
from sklearn.linear_model import LinearRegression, Lasso, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, r2_score
from sklearn.model_selection import cross_validate
import warnings
warnings.filterwarnings('ignore')

# 1. OLS 
lr_ols = LinearRegression()
lr_ols.fit(X_train, y_train)
y_pred_ols_train = lr_ols.predict(X_train)

cv_ols = cross_validate(
    LinearRegression(), X_train, y_train, cv=5,
    scoring=['neg_mean_absolute_percentage_error', 'r2']
)

# 2. Lasso (alpha tuned by LassoCV) - penalize L1 
lasso_cv = LassoCV(cv=5, random_state=42, max_iter=20000)
lasso_cv.fit(X_train, y_train)
best_alpha = lasso_cv.alpha_

lasso = Lasso(alpha=best_alpha, max_iter=20000, random_state=42)
lasso.fit(X_train, y_train)
y_pred_lasso_train = lasso.predict(X_train)

cv_lasso = cross_validate(
    Lasso(alpha=best_alpha, max_iter=20000, random_state=42),
    X_train, y_train, cv=5,
    scoring=['neg_mean_absolute_percentage_error', 'r2']
)

# 3. Random Forest Regression (default baseline)
rf_base = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_base.fit(X_train, y_train)
y_pred_rf_train = rf_base.predict(X_train)

cv_rf = cross_validate(
    RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1),
    X_train, y_train, cv=5,
    scoring=['neg_mean_absolute_percentage_error', 'r2']
)

# 4. Comparison table
results = {}
for name, y_pred, cv_res in [
    ('OLS',           y_pred_ols_train,   cv_ols),
    ('Lasso',         y_pred_lasso_train, cv_lasso),
    ('Random Forest', y_pred_rf_train,    cv_rf),
]:
    results[name] = {
        'Train MAPE': round(mean_absolute_percentage_error(y_train, y_pred), 4),
        'CV MAPE'   : round(-cv_res['test_neg_mean_absolute_percentage_error'].mean(), 4),
        'Train R²'  : round(r2_score(y_train, y_pred), 4),
        'CV R²'     : round(cv_res['test_r2'].mean(), 4),
    }

print('Base Model Comparison — OLS vs Lasso vs Random Forest')
display(pd.DataFrame(results).T)
print(f'\nLasso best alpha (LassoCV) : {best_alpha:.6f}')
# Out:
# Base Model Comparison — OLS vs Lasso vs Random Forest
#                Train MAPE  CV MAPE  Train R²   CV R²
# OLS                0.0448   0.0462    0.7161  0.6956
# Lasso              0.0642   0.0646    0.4812  0.4728
# Random Forest      0.0148   0.0404    0.9643  0.7405
# Lasso best alpha (LassoCV) : 0.073262

# %% [markdown]
# **c. CRITIQUE: Pros and Cons of each model in the context of Airbnb Pricing Prediction**
#
# | Model | Advantages | Disadvantages |
# |---|---|---|
# | **OLS regression** | Simple, fast, and interpretable — ideal for predicting a continuous target against many independent variables to see which features push price up or down. Works well as a baseline, with a moderate train–CV MAPE gap (~0.0020). | Assumes a straight-line relationship between features and price, which is unrealistic here (only 13 variables with moderate linear correlation were chosen from the Part 1 scatter matrix). Requires strict data prep: log transform, scaling, and outlier handling. |
# | **Lasso regression** | Automatically reduces the influence of irrelevant features by shrinking coefficients toward zero, especially useful with 90+ features, many of which may not matter. Slightly more reliable than OLS when features are correlated (e.g. accommodates, beds, bathrooms). | Still assumes linear relationships, so it shares OLS's core limitation. If the best alpha is very small, Lasso effectively becomes OLS. |
# | **Random Forest (bagging)** | Handles non-linear relationships without extra feature transforms (though price still needs transforming). Works with mixed feature types (numeric, binary, encoded categorical) and requires no feature scaling. Provides useful feature-importance analysis. | Tends to fit the training set very closely (low training MAPE), which doesn't always generalise to unseen data. Also a "black box" — hard to explain individual predictions without deeper interpretability work. |

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 2. Model Evaluation Strategy (2 marks)
#
# Describe how you will train and evaluate your models.
# - Explain how cross-validation will be implemented
# - Specify the evaluation metric you will use
# - Describe how model performance will be compared
# - Briefly justify your choices
# <hr style="width:25%;margin-left:0;">

# %% [markdown]
# ---- Add your written answer here ------

# %% [markdown]
# `a. Cross-validation:`
#
# To ensure accuracy and prevent overfitting on test set. 5-fold cross-validation will be used:
# - The training set (3,735 rows) is split into 5 folds; each fold will utilize 4 parts for training and one part for testing.
# - In each sequequent run, a different part was used for testing, while the remaing 4 part were used for training.
# - The final error was calculated as the average of the errors obtained from all 5 runs.
#
# `b. Evaluation metric:`
#
# - We use two metrics **_Mean Absolute Percentage Error (MAPE)_**: _The average size of the prediction error expressed as a percentage of the true value_ and **_R_squared score_**: _The proportion of variance in the target that the model explains_ on log-transformed price, consistent with the Kaggle competition metric. Futhermore, we can also use a diverse range of evaluation metrics to allow for a comprehensive evalution.
#
# The three models also show distinct bias–variance behaviour Base on evaluation metric:
#
# - Lasso underfits: its training and cross-validated R² are both low (≈0.47–0.48), indicating that the default regularisation is too strong and suppresses useful signal — it is the weakest model.
# - OLS is a stable, well-generalised baseline, with a very small train–CV gap (R² 0.7161 → 0.6956), but it is limited to linear relationships and therefore cannot capture the non-linear.
# - Random Forest shows the opposite profile: a large train–CV gap (R² 0.9643 → 0.7405) that signals overfitting, yet it still delivers the best generalisation of the three because it captures the non-linear interactions the linear models miss.
#
# - Using both together gives a clearer picture where MAPE shows raw prediction accuracy, while R² shows how well the model captures the overall pattern in the data.
#
# `c. Comparison:`
#
# In overall, models are ranked by mean CV MAPE (lower = better). Standard deviation across folds will also be reported to assess stability. The best-performing model will be retrained on the full training AND test set for Kaggle submission. The well-performed model states that they are more suitable to use to predict the housing airbnb price while the findings also revealed that some features directly affect the price of the property. **This can help the Airbn's host use it to make an effective pricing strategy.**
#
# `Model of choice:`
# - Chosen model: **Random Forest**. It is selected because it gives the strongest cross-validated accuracy, which is the relevant criterion for unseen data, and because its tree-based structure matches the non-linearity observed in the data. We dive into diagnostic first

# %% [markdown]
# **RESIDUAL DIAGNOSTIC: linear regression (OLS) vs Lasso vs Random Forest (Regressor)**

# %%
# Residual diagnostic plots — OLS, Lasso, Random Forest
models_plot = [
    ('OLS',           y_pred_ols_train,   'steelblue'),
    ('Lasso',         y_pred_lasso_train, 'darkorange'),
    ('Random Forest', y_pred_rf_train,    'seagreen'),
]

fig, axes = plt.subplots(3, 2, figsize=(13, 11))
for row, (name, y_pred, color) in enumerate(models_plot):
    res = y_train - y_pred
    axes[row, 0].scatter(y_pred, res, alpha=0.2, s=8, color=color)
    axes[row, 0].axhline(0, color='red', linestyle='--', linewidth=1)
    axes[row, 0].set_xlabel('Predicted log(price)')
    axes[row, 0].set_ylabel('Residual')
    axes[row, 0].set_title(f'{name} — Residuals vs Fitted')
    axes[row, 1].hist(res, bins=50, color=color, edgecolor='none')
    axes[row, 1].axvline(0, color='red', linestyle='--', linewidth=1)
    axes[row, 1].set_xlabel('Residual')
    axes[row, 1].set_title(f'{name} — Residual Distribution')

plt.suptitle('Base Model Comparison — Diagnostic Plots', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment on residual diagnostic plot**
#
# - _OLS and Lasso_
#
# Show a similar pattern: residuals are not evenly spread around zero, there is a slight fan shape, where errors are larger for higher-priced listings. This is expected for a linear model predicting log-price on a dataset with many extreme values. Both models also have heavier tails in the residual distribution compared to Random Forest.
#
# - _Random Forest_
#
# Has much tighter residuals on the training set, ideally being zero in many cases. This confirms that it is fitting the training data very closely. While this looks impressive on training data, the higher gap between train MAPE and CV MAPE (seen in the comparison table) confirms that this tight fit does not fully carry over to unseen listings.
#
# Overall, the diagnostic plots confirm that the linear models are slightly underfitting (missing price patterns they cannot express as straight lines), while Random Forest is overfitting on training data. Despite of that, with the impressive error in training data, we decided to choose Random Forest as a best-perfored model until now.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 3. Model Training and Hyperparameter Tuning (2 marks)
#
# Train and refine the initial model set by tuning their hyperparameters using cross-validation.
# - Report the optimal hyperparameter values for each model
# - Present and compare model performance using the chosen evaluation metric(s)
# - Briefly interpret the results, including any evidence of overfitting or underfitting
# <hr style="width:25%;margin-left:0;">

# %% [markdown]
# **a. Pipeline Hyperparameter tunning for 3 models**

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.metrics import mean_absolute_percentage_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# Pipeline definition creation
'''
Linear models: RobustScaler (resistant to outliers) + model
Random Forest: no scaling needed (tree splits are scale-invariant)`
'''
ols_pipe = Pipeline([('scaler', RobustScaler()), ('model', LinearRegression())]) # OLS pipline
lasso_pipe = Pipeline([('scaler', RobustScaler()), ('model', Lasso(max_iter=20000))]) # Lasso pipiline
rf_pipe = Pipeline([('model', RandomForestRegressor(random_state=42, n_jobs=-1))]) # Random Forest pipiline

# Create hyperparameter grids
ols_grid = {'model__fit_intercept': [True, False]}

lasso_grid = {'model__alpha': np.logspace(-4, 1, 40).tolist()}

rf_grid = {
    'model__n_estimators'  : [100, 300, 500],
    'model__max_depth'     : [10, 20, None],
    'model__min_samples_leaf': [1, 4],
    'model__max_features'  : ['sqrt', 0.5],
}

# GridSearchCV (5-fold, scored by MAPE)
searches = {
    'OLS'          : GridSearchCV(ols_pipe,   ols_grid,   cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1),
    'Lasso'        : GridSearchCV(lasso_pipe, lasso_grid, cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1),
    'Random Forest': GridSearchCV(rf_pipe,    rf_grid,    cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1),
}

for name, gs in searches.items():
    gs.fit(X_train, y_train)
    print(f'{name}')
    print(f'  Best params : {gs.best_params_}')
    print(f'  Best CV MAPE: {-gs.best_score_:.4f}\n')

# Performance table: train vs CV (MAPE & R²)
tuned_results = {}
best_estimators = {}
for name, gs in searches.items():
    best = gs.best_estimator_
    best_estimators[name] = best
    y_pred_train = best.predict(X_train)
    cv_res = cross_validate(
        best, X_train, y_train, cv=5,
        scoring=['neg_mean_absolute_percentage_error', 'r2']
    )
    tuned_results[name] = {
        'Train MAPE': round(mean_absolute_percentage_error(y_train, y_pred_train), 4),
        'CV MAPE'   : round(-cv_res['test_neg_mean_absolute_percentage_error'].mean(), 4),
        'Gap (overfit?)': round(
            mean_absolute_percentage_error(y_train, y_pred_train)
            - (-cv_res['test_neg_mean_absolute_percentage_error'].mean()), 4),
        'Train R²'  : round(r2_score(y_train, y_pred_train), 4),
        'CV R²'     : round(cv_res['test_r2'].mean(), 4),
    }

results_df = pd.DataFrame(tuned_results).T
print('Tuned Model Comparison — MAPE & R² (5-fold CV)')
display(results_df)
print('Note: Gap = Train MAPE − CV MAPE. Negative gap → overfitting (train much better than CV).')
print('      Gap near 0 → good generalisation. Positive gap → underfitting.')

# %% [markdown]
# | Model | Best hyperparameters | Best CV MAPE |
# |---|---|---|
# | **OLS** | `fit_intercept = False` | 0.0462 |
# | **Lasso** | `alpha = 0.0001` | 0.0462 |
# | **Random Forest** | `n_estimators = 500`, `max_depth = None`, `min_samples_leaf = 1`, `max_features = 0.5` | 0.0398 |

# %% [markdown]
# **Comment and interpretation after tunning hyperparameter**
#
# <hr style="width:50%;margin-left:0;">
#
# **_OLS (Linear Regression)_**
#
# OLS has essentially no meaningful hyperparameters to tune. The only choice is whether to include an intercept, and the result confirms that including it (fit_intercept = True) produces a marginally better fit. The training and CV MAPE are close to each other (gap ≈ 0), which confirms that OLS is not overfitting but show the sign of underfitting because the model is too simple to capture all the complexity of target variable price relationship.
#
# However, the CV R² of 0.69 tells us that OLS can only explain about 70% of the variation in listing price using a linear combination of features. Given that price depends on complex interactions. A private room in a beachfront suburb is not simply "location effect + room type effect" added together — this ceiling is expected. OLS is doing the best it can within its structural limits.
#
# <hr style="width:50%;margin-left:0;">
#
# <hr style="width:50%;margin-left:0;">
#
# **_Lasso_**
#
# The best alpha found by cross-validation was 0.000, a very small value close to zero. This is a key finding: when alpha is near zero, the L1 penalty is barely active, and Lasso reduces almost entirely to OLS. This explains why both models' CV MAPE and R² are nearly identical.
#
# What this tells us is that in this dataset, the problem is not that we have too many noisy features pulling the model in wrong directions. It is that the relationship between features and price is genuinely non-linear, which no amount of coefficient shrinkage can fix. Lasso's intended benefit (removing weak features) had almost no effect here because most features are contributing some signal, just not in a linear way.
#
# The gap for Lasso (Train MAPE − CV MAPE ≈ 0.00) is similarly small, confirming there is no meaningful overfitting, but both models generalise predictably, just not very accurately.
# <hr style="width:50%;margin-left:0;">
#
# <hr style="width:50%;margin-left:0;">
#
# **_Random Forest_**
#
# Random Forest improve but not too significantly
#
# The training MAPE of 0.039 is dramatically higher than the CV MAPE of 0.014. This large negative gap is a clear sign of overfitting. The reason because the model has learned the training data in fine detail (up to 90 selected features) and cannot fully generalise that knowledge to unseen properties.
#
# Importantly, even with this overfitting, the CV MAPE of Random Forest is still lower than both OLS and Lasso, but not significantly. This means that despite memorising too much of the training data, Random Forest still captures enough genuine price patterns to outperform the linear models on new listings. This makes it the strongest of the three initial models.
#
# The CV R² of 0.749 further confirms this — Random Forest explains 74.9% of price variation on held-out data, compared to 69.6% for OLS/Lasso.
# <hr style="width:50%;margin-left:0;">
#
#
# > The results point to a clear conclusion: the relationship between listing features and price is non-linear, which the two linear models structurally cannot handle regardless of tuning. Random Forest is the natural next step, though its overfitting leaves room for improvement, which motivates the move to boosting models (XGBoost, CatBoost) in Section 5.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 4. Best Model and Kaggle Submission (2 marks)
#
# Select your best-performing model and generate predictions for the test dataset.
# - Submit your predictions to Kaggle
# - Report your Kaggle score and ranking (include screenshots)
# - Briefly comment on your performance
# <hr style="width:25%;margin-left:0;">

# %%
# Kaggle submission — Random Forest (tuned via GridSearchCV in Section 3)
# best_estimators['Random Forest'] is the best pipeline found — predicts in log-price space
y_test_pred_rf = np.expm1(best_estimators['Random Forest'].predict(X_test))

submission_rf = pd.DataFrame({
    'ID'   : raw_test_df['ID'],
    'price': np.round(y_test_pred_rf, 2)
})
submission_rf.to_csv('submission_rf.csv', index=False)
submission_rf.head(10)

# %% [markdown]
# ### Notice:
# - The below version is the very initial version we run the model with `basically original 26 variables` as base assignment requirements:

# %% [markdown]
# <img src="ranking_score%20_image/ranking_first_attemt.jpeg" alt="Leaderboard" width="700">
#
# <img src="ranking_score%20_image/score_first_attempt.png" alt="RF submission" width="500">

# %% [markdown]
# **Comment perfomance**
#
# Our first Kaggle submission using the tuned Random Forest achieved a low public leaderboard score of 0.64. This reflects the model's ability to pick up non-linear patterns in the data, performing meaningfully better than the linear baselines. The fact that we just use only 26 initial features so that it was limited by overfitting on the training set because some of beginning features are uncapable to explain further the target. The most difficult listings to predict were amentities strings to define which properties in less or more common, or which neighborhood suburn are highly prefered to rent, where our team ignore them for the first time.

# %% [markdown]
# <hr style="width:25%;margin-left:0;">
#
# #### 5. Model Improvement and Reflection (2 marks)
#
# Propose and implement at least one improvement to your model or modelling approach.
# - Clearly describe the change you made
# - Provide updated Kaggle results (include screenshots)
# - Briefly discuss whether the improvement was effective
# - Identify the main limitation(s) preventing your model from achieving a top ranking in the competition
#
# <hr style="width:25%;margin-left:0;">

# %% [markdown]
# **a. Feature re-selection:**
#
# Our first model used only the original 26 variables. After reviewing which features were driving predictions, we rebuilt the feature set with several targeted improvements:
#
# 1. `Amenities`:
#
# - The raw amenities column contains a free-text list with over 2,000 unique items. Rather than just counting the total number of amenities, we extracted the top 25 most frequently listed and price-relevant amenities as individual binary columns (1 = present, 0 = absent). This allows the model to distinguish, for example, that a listing with a pool commands a higher price — a signal that a plain count misses entirely.
#
# 2. `Listing name keywords`
#
# - We extracted keyword-based binary flags from the listing name (e.g. "pool", "ocean view", "studio") to capture host-marketed features not found elsewhere in the structured data.
#
# 3. `Location`:
#
# - Raw latitude and longitude capture location basically but no reference, but not meaningfully. We replaced them with two purpose-built variables:
#     - `dist_to_cbd` (straight-line distance to Brisbane CBD)
#     - `neighbourhood_te` (target-encoded suburb price signal). KMeans clustering was also applied to group listings into geographic zones, fitted on training data only to prevent leakage.
#
# 5. `Neighbourhood`:
#
# - Instead of collapsing 95+ suburbs into just "top 5 + other" (which throws away most geographic information), we switched to target encoding using KFold — a leakage-free method that maps each suburb to a price signal based on the training data.
#
# <hr style="width:25%;margin-left:0;">
# <hr style="width:25%;margin-left:0;">
#
# **b. Tunning hyperparameter**
#
# - Given that price data contains outliers and non-linear patterns, the priority was not maximising fit on the training set but closing the gap between training and cross-validation error. Tuning regularisation-related parameters. We mannually set low range of depth limits and leaf size to directly addresses the overfitting observed in the initial model.
#
# **Random Forest Grid — Justification (overfitting-focused)**
#
# | Hyperparameter | Values | Role | Why chosen (overfitting context) |
# |---|---|---|---|
# | `n_estimators` | 100, 300, 500 | Number of trees | More trees reduce variance and stabilise predictions; does not itself cause overfitting (bagging averages over trees). |
# | `max_depth` | 10, 20, None | Tree depth | Main lever against overfitting, capping depth stops fully-grown trees from memorising the training data, aiming to minimize the max depth |
# | `min_samples_leaf` | 1, 4 | Min samples per leaf | Larger leaves smooth predictions and resist price outliers, narrowing the train–CV gap. |
# | `max_features` | 'sqrt', 0.5 | Features per split | Fewer features decorrelate the trees, increasing diversity and lowering variance. |
#
# #### **Justify why these varibles is effective**
#
# Comparing the top-20 feature importances before and after re-engineering (see charts below) shows a clear shift:
#
# - neighbourhood_te (rank 6): the target-encoded location carries genuine signal.
# - has_pool (rank 16): an amenity binary makes the list, showing that extracting individual binaries captures value that amenities_count alone cannot.
# - bath_to_bedroom_ratio (rank 18): the engineered ratio is being used by the model.
# - host_acceptance_rate (rank 19): usable once converted from a percentage string to a numeric value.
#
# → This is direct evidence that the feature re-selection produced usable signal. After re-selection, the engineered features all appear in the top-20 MDI, indicating that they contribute meaningfully to the model's decisions. Importance is also more evenly distributed (the leading feature falls from 0.30 to 0.175), reducing the model's reliance on any single variable. That said, MDI only reflects how much a feature is used, not how well the model predicts; the effectiveness of the improvement is confirmed by the average score achieved on the Kaggle test-set submission.
#
# - Features that possibly drive price (feature importance): size and location remain at the top in both versions (room_type, accommodates, bedrooms, bathrooms, dist_to_cbd) — a consistent and credible result. These variables can serve as a basis for decision-making, and warrant deeper exploration to extract additional predictive gains.

# %% [markdown]
# Below is the top 20 feature importance we train on **the 26-feature Random Forest model (left-side)** and **most updated Random forest model (right side)**:
#
# <img src="output/ouput 1.png" width="600">
#
# <img src="output/output 2.png" width="600">
#
#
# #### FINAL SCORE with RANDOM FOREST
#
# <img src="output/RF_improved_score.png" width="600">

# %% [markdown]
# **c. Main limitation preventing a higher ranking**
#
# - **_Persistent overfitting:_** Despite tuning, our training MAPE remains noticeably lower than the cross-validated error. Tree-based models learn the training listings in fine detail, and with only ~3,700 training rows, some of that detail is noise rather than real pattern. Stronger regularisation (shallower trees, larger minimum leaf size) partially addresses this but cannot eliminate it entirely.
#
# - **_Review text was not used:_** A top ranking might require richer inputs in reality, for example, we could have using sentimental analysis to analyse text and description of listings. This was a conscious trade-off given lack of in-depth understanding but represents a meaningful missed signal.
#  And some significant correlation between features and price we're missing during the feature prrocess.
#
# - **_Neighbourhood encoding ceiling_:** Even with KFold target encoding, suburbs with very few listings produce unreliable encoded values. Sparse suburbs effectively fall back to the global mean, losing local price information. So that we are unable to capture the full feature relationship in-depth.

# %% [markdown]
# **c. Extension model set: XGBoost and CatBoost**

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
# import catboost
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

# %%
# 1. BASELINE BENCHMARK
from sklearn.model_selection import RandomizedSearchCV, cross_val_score

print("Baseline CV MAPE (5-fold):")
baseline = {
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'XGBoost'      : XGBRegressor(n_estimators=200, random_state=42, verbosity=0),
    'CatBoost'   : CatBoostRegressor(n_estimators=200, random_state=42, verbose=0)
}
for name, model in baseline.items():
    scores = cross_val_score(model, X_train, y_train, cv=5,
                             scoring='neg_mean_absolute_percentage_error', n_jobs=-1)
    print(f"  {name}: {-scores.mean():.4f} ± {scores.std():.4f}")

# 2. HYPERPARAMETER TUNING
tree_param_distributions = {
    'n_estimators'    : [100, 200, 300, 500],
    'max_depth'       : [10, 20, 30, None],
    'max_features'    : ['sqrt', 'log2', 0.5, 0.8],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4, 8]
}

# Expanded XGBoost grid — more trees + regularisation params
xgb_gs = RandomizedSearchCV(
    XGBRegressor(objective='reg:absoluteerror', eval_metric='mape', random_state=42, verbosity=0, tree_method='hist'),
    param_distributions={
        'n_estimators'    : [300, 500, 1000, 2000],
        'max_depth'       : [3, 4, 6, 8],
        'eta'             : [0.005, 0.01, 0.05, 0.1],
        'subsample'       : [0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.5, 0.7, 0.8, 1.0],
        'min_child_weight': [1, 3, 5, 10],
        'reg_alpha'       : [0, 0.01, 0.1, 1.0],
        'reg_lambda'      : [0.5, 1.0, 2.0, 5.0],
    },
    n_iter=30, cv=5, scoring='neg_mean_absolute_percentage_error',
    n_jobs=-1, random_state=42
)

rf_rs = RandomizedSearchCV(
    RandomForestRegressor(random_state=42, criterion='absolute_error'),
    param_distributions=tree_param_distributions,
    n_iter=20, cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1, random_state=42
)

cat_rs = RandomizedSearchCV(
    CatBoostRegressor(loss_function='MAPE', random_state=42, verbose=0),
    param_distributions={
        'depth'          : [4, 6, 8, 10],
        'l2_leaf_reg'    : [1, 3, 5, 7, 9],
        'learning_rate'  : [0.01, 0.03, 0.05, 0.1, 0.2],
        'iterations'     : [200, 300, 500, 1000]
    },
    n_iter=20, cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1, random_state=42
)

for search in [xgb_gs, rf_rs, cat_rs]:
    search.fit(X_train, y_train)

print("\nTuning Results:")

print("Model: XGBooost\n")
print(f"Best Params: {xgb_gs.best_params_}\n")
print(f" CV MAPE: {-xgb_gs.best_score_:.4f}\n")

print("Model: Random Forest\n")
print(f"Best Params: {rf_rs.best_params_}\n")
print(f" CV MAPE: {-rf_rs.best_score_:.4f}\n")

print("Model: CatBoost\n")
print(f"Best Params: {cat_rs.best_params_}\n")
print(f" CV MAPE: {-cat_rs.best_score_:.4f}\n")

# %% [markdown]
# ---- Add your written answer here ------

# %% [markdown]
# #### FINAL SCORE with XGBOOST model
#
# <img src="output/XGBoost_score.png" width="600">

# %% [markdown]
# ### Feature importance analysis

# %% [markdown]
# **a. Feature importance with Random Forecast**

# %%
# RF model is inside the Pipeline under step name 'model'
rf_model = best_estimators['Random Forest'].named_steps['model']

# MDI Feature Importance (built-in to RF) 
importances = pd.Series(rf_model.feature_importances_, index=X_train.columns)
top20 = importances.nlargest(20).sort_values()

fig, ax = plt.subplots(figsize=(9, 7))
top20.plot(kind='barh', color='steelblue', ax=ax)
ax.set_title('Random Forest — Top 20 Feature Importances (MDI)', fontsize=12)
ax.set_xlabel('Mean Decrease in Impurity (MDI)')
ax.axvline(importances.mean(), color='red', linestyle='--',
           linewidth=1, label=f'Mean importance ({importances.mean():.4f})')
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# Summary table
imp_table = (
    importances
    .sort_values(ascending=False)
    .reset_index()
    .rename(columns={'index': 'Feature', 0: 'Importance'})
    .head(20)
    .reset_index(drop=True)
)
imp_table.index += 1
print('Top 20 features by MDI importance:')
display(imp_table)

# %% [markdown]
# #### **Comment**
#
# The chart and table above rank the top 20 features by how much each one helps the model make better splits across all decision trees — features used more often to separate high-price from low-price listings score higher.
#
# - _Listing property type:_ strongest signal
#
# Airbnb Pricing significantly influenced on the two room variables: Entire room/ apt and private room. This may suggest that whether a guest rents an entire property or a single room is the strongest determinant of price.
#
# - _Capacity_: core pricing signal
#
# This categories is consistently matched with correlation heatmap show above, we can confirm their linear realationship between them and price, indicating that listing scale is a core pricing signal. `accommodates`, `bedrooms`, `bathrooms`, and `beds` all rank highly, with the engineered `bath_to_bedroom_ratio` also entering the list.
#
# - _Location_: strong and consistently engineered
#
# One again, location is the next major driver when mostly engineered variables like target-encoded `neighbourhood` and `dist_to_cbd` contributes meaningfully.
#
# - _Host, availability, and amenity features_
#
# `Host_listings_count`, `host_experience_days`, and `host_acceptance_rate` capture host professionalism and behaviour; `availability_rate` and `availability_30` reflect booking pressure; and among amenities, the engineered has_pool and amenities_count both earn places, this is evidence that extracting individual high-value amenities adds value beyond a simple count.
#
# > **Trade-off here: between host and guests**
#
# MDI measures how frequently and how cleanly a feature is used in tree splits. It does not tell us the direction of the effect or whether the feature is the true cause of price differences. When two features are correlated (e.g. bedrooms and accommodates), importance can be split unevenly between them, making one appear less influential than it really is. The scores here should be read as a guide to which features the model found useful, not as a definitive ranking of real-world pricing drivers.

# %% [markdown]
# **b. Extension: SHAP feature selection for XGBoost and CatBoost**

# %%
# import shap

# # TreeExplainer is exact and fast for XGBoost
# explainer   = shap.TreeExplainer(xgb_gs.best_estimator_)
# shap_values = explainer.shap_values(X_train)

# # Mean absolute SHAP = model-wide feature importance
# shap_imp = pd.Series(
#     np.abs(shap_values).mean(axis=0),
#     index=X_train.columns
# ).sort_values(ascending=False)

# # Plot 1: mean |SHAP| bar chart 
# fig, ax = plt.subplots(figsize=(10, 9))
# shap_imp.head(50).sort_values().plot.barh(ax=ax, color='steelblue')
# ax.set_title('XGBoost — Top 50 Features by Mean |SHAP|', fontsize=12)
# ax.set_xlabel('Mean |SHAP value|  (impact on log-price)')
# plt.tight_layout()
# plt.show()

# # Select top 50 
# top50_shap = shap_imp.nlargest(50).index.tolist()
# print(f"Top 50 features by SHAP importance:")
# display(shap_imp.head(50).reset_index().rename(
#     columns={'index': 'Feature', 0: 'Mean |SHAP|'}).round(5))

# %% [markdown]
# c. Re-tun XGBoost on top-50 features

# %%
# # Step 1: Subset to SHAP top-50 features 
# X_train_50 = X_train[top50_shap]
# X_test_50  = X_test[top50_shap]
# print(f"Features: {X_train.shape[1]} → {len(top50_shap)}")

# # Step 2: Re-tune XGBoost on top-50 features 
# xgb_top50 = RandomizedSearchCV(
#     XGBRegressor(objective='reg:absoluteerror', eval_metric='mape', random_state=42, verbosity=0, tree_method='hist'),
#     param_distributions={
#         'n_estimators'    : [300, 500, 1000, 2000],
#         'max_depth'       : [3, 4, 6, 8],
#         'eta'             : [0.005, 0.01, 0.05, 0.1],
#         'subsample'       : [0.6, 0.7, 0.8, 0.9, 1.0],
#         'colsample_bytree': [0.5, 0.7, 0.8, 1.0],
#         'min_child_weight': [1, 3, 5, 10],
#         'reg_alpha'       : [0, 0.01, 0.1, 1.0],
#         'reg_lambda'      : [0.5, 1.0, 2.0, 5.0],
#     },
#     n_iter=30, cv=5, scoring='neg_mean_absolute_percentage_error',
#     n_jobs=-1, random_state=42
# )
# xgb_top50.fit(X_train_50, y_train)

# # Step 3: Compare full-feature vs top-50
# comparison = pd.DataFrame({
#     'Model'   : ['XGBoost — all features', 'XGBoost — SHAP top 50'],
#     'n_features': [X_train.shape[1], 50],
#     'CV MAPE' : [-xgb_gs.best_score_, -xgb_top50.best_score_],
# }).round({'CV MAPE': 4})
# display(comparison)

# # Step 4: Submission 
# best_xgb    = xgb_top50 if -xgb_top50.best_score_ < -xgb_gs.best_score_ else xgb_gs
# best_X_test = X_test_50 if best_xgb is xgb_top50 else X_test

# y_pred = np.expm1(best_xgb.best_estimator_.predict(best_X_test))
# submission = pd.DataFrame({'ID': raw_test_df['ID'], 'price': np.round(y_pred, 2)})
# submission.to_csv('submission_xgb_shap50.csv', index=False)
# print(f"\nBest XGBoost CV MAPE: {min(-xgb_gs.best_score_, -xgb_top50.best_score_):.4f}")
# print(f"Saved submission_xgb_shap50.csv — {len(submission)} rows")
# submission.head()

# %%
# # Step 2: Re-tune XGBoost on top-50 features 
# cat_top50 = RandomizedSearchCV(
#     CatBoostRegressor(loss_function='MAPE', random_state=42, verbose=0),
#     param_distributions={
#         'depth'          : [4, 6, 8, 10],
#         'l2_leaf_reg'    : [1, 3, 5, 7, 9],
#         'learning_rate'  : [0.01, 0.03, 0.05, 0.1, 0.2],
#         'iterations'     : [200, 300, 500, 1000]
#     },
#     n_iter=20, cv=5, scoring='neg_mean_absolute_percentage_error', n_jobs=-1, random_state=42
# )
# cat_top50.fit(X_train_50, y_train)

# #  Step 3: Compare full-feature vs top-50 
# comparison = pd.DataFrame({
#     'Model'   : ['CatBoost — all features', 'CatBoost — SHAP top 50'],
#     'n_features': [X_train.shape[1], 50],
#     'CV MAPE' : [-cat_rs.best_score_, -cat_top50.best_score_],
# }).round({'CV MAPE': 4})
# display(comparison)

# # Step 4: Submission 
# best_cat    = cat_top50 if -cat_top50.best_score_ < -cat_rs.best_score_ else cat_rs
# best_X_test = X_test_50 if best_cat is cat_top50 else X_test

# y_pred = np.expm1(best_cat.best_estimator_.predict(best_X_test))
# submission = pd.DataFrame({'ID': raw_test_df['ID'], 'price': np.round(y_pred, 2)})
# submission.to_csv('submission_cat_shap50.csv', index=False)
# print(f"\nBest CatBoost CV MAPE: {min(-cat_rs.best_score_, -cat_top50.best_score_):.4f}")
# print(f"Saved submission_cat_shap50.csv — {len(submission)} rows")
# submission.head()

# %% [markdown]
# ---
# ---
# ## Marking Criteria
#
# To receive full marks, your solutions must satisfy the following criteria:
#
# - Correct understanding of the problem and adequate use of additional research
# - Analysis follows best practices discussed in lectures and tutorials
# - Use of intuitive and easily understood visualisations and summary statistic tables
# - Use of appropriate predictive methods in the context of the given problem
# - Python code is clean, concise, and executes without errors
# - Written explanations are clear, complete, and easy to understand
# - Forecasts are correctly generated and uploaded to Kaggle
# - Results are reproducible from the submitted code
# - The assignment notebook is well-organised and easy to follow
# - Video Presentation:
#     - Duration less than 15 minutes
#     - Each team member delivers a 5-minute presentation on their assigned task
#     - All assignment questions must be discussed in the video
#     - Your code must be clearly readable in the video
#     - Discuss both the actions you took and, more importantly, the reasoning behind these actions, explaining the significance of key steps
#     - Ensure that both your face and Jupyter Notebook are clearly visible during the recording
# - Failure to meet the above criteria will result in a deduction of marks
#
#
# ---
# ---
